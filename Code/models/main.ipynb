# %% [markdown]
# ## Reduce the size of the dataset and preprocess the data

# %% [markdown]
# Import

# %%
# Resizing img
import os
import argparse
from PIL import Image
from sklearn.model_selection import train_test_split

# Make vocab
import json
import re
from collections import defaultdict

# Preprocess data
import glob
import numpy as np

# Build dataset
from torch.utils.data import Dataset
from torchvision import transforms
from torch.utils.data import DataLoader

# Models
import torch
import torch.nn as nn
import torchvision.models as models
import torch.nn.functional as F

# Training
import time
from torch import optim

# %% [markdown]
# Define paths

# %%
img_pth = 'dataset\img'
ann_pth = 'dataset\\ann'
qst_pth = 'dataset\qst'
out_img_pth = 'preprocessed\img'
out_data_pth = 'preprocessed\data'
out_vocab_pth = 'preprocessed\\vocab'
out_ann_pth = 'preprocessed\\ann'
out_qst_pth = 'preprocessed\qst'
ckpt_pth = 'late_fusion\ckpt'
log_pth = 'late_fusion\log'

# %% [markdown]
# Preprocess images

# %%
def resize_image(image, size):
    """Resize an image to the given size."""
    return image.resize(size, Image.Resampling.LANCZOS)

def resize_images(input_dir, output_dir, size, split_ratio):
    """Resize the images in 'input_dir' and save into 'output_dir'."""
    for idir in os.scandir(input_dir):
        if not idir.is_dir():
            print('No valid directory')
            continue
        if not os.path.exists(output_dir+'\\'+idir.name):
            os.makedirs(output_dir+'\\'+idir.name)
        else:
            for file in os.listdir(output_dir+'\\'+idir.name):
                if os.path.isfile(os.path.join(output_dir+'\\'+idir.name, file)):
                    os.remove(os.path.join(output_dir+'\\'+idir.name, file))
                      
        images = os.listdir(idir.path)
        images, _ = train_test_split(images,
                                     test_size=split_ratio,
                                     shuffle=False)
        n_images = len(images)
        for id, image in enumerate(images):
            try:
                with open(os.path.join(idir.path, image), 'r+b') as f:
                    with Image.open(f) as img:
                        img = resize_image(img, size)
                        img.save(os.path.join(output_dir+'\\'+idir.name, image), img.format)
            except(IOError, SyntaxError) as e:
                pass
            if (id+1) % 500 == 0:
                print("[{}/{}] resized images and saved into '{}'."
                      .format(id+1, n_images, output_dir+'\\'+idir.name))
                    
def main():

    input_dir = img_pth
    output_dir = out_img_pth
    image_size = [224, 224]
    split_ratio = 0.95
    resize_images(input_dir, output_dir, image_size, split_ratio)
    
main()
# Out:
# [500/1000] resized images and saved into 'preprocessed\img\img_test'.
# [1000/1000] resized images and saved into 'preprocessed\img\img_test'.
# [500/1000] resized images and saved into 'preprocessed\img\img_train'.
# [1000/1000] resized images and saved into 'preprocessed\img\img_train'.
# [500/500] resized images and saved into 'preprocessed\img\img_val'.

# %% [markdown]
# Removing questions and annotations that doesnt belong to the images

# %%
def removing(out_img_pth, ann_pth, qst_pth):

    test_ids = []
    train_ids = []
    val_ids = []
    for idir in os.scandir(out_img_pth):
        for file in os.listdir(idir):
            components = file.split('_')
            image_id = components[-1].split('.')[0]
            numeric_part = int(image_id)
            if 'test' in idir.name:
                test_ids.append(numeric_part)
            elif 'train' in idir.name:
                train_ids.append(numeric_part)
            elif 'val' in idir.name:
                val_ids.append(numeric_part)
    
    for idir in os.scandir(ann_pth):
        if 'test' in idir.name:
            ids = test_ids
        elif 'train' in idir.name:
            ids = train_ids
        elif 'val' in idir.name:
            ids = val_ids
        
        for file in os.listdir(idir):
            path = os.path.join(idir, file)
            with open(path, 'r') as f:
                data = json.load(f)
            annotations = data['annotations']
            prelen = len(annotations)
            labels = dict()
            number = 0
            for label in annotations:
                    if int(label['image_id']) in ids:
                        labels.update({number: label})   
                        number += 1
            print(f'{len(labels)} remaining annotations of {prelen} in {file}')
            data['annotations'] = labels
            with open(out_ann_pth + '\\' + file, 'w') as f:
                json.dump(data, f)
    
    for idir in os.scandir(qst_pth):
        if 'test' in idir.name:
            ids = test_ids
        elif 'train' in idir.name:
            ids = train_ids
        elif 'val' in idir.name:
            ids = val_ids
            
        for file in os.listdir(idir):
            path = os.path.join(idir, file)
            with open(path, 'r') as f:
                data = json.load(f)
            questions = data['questions']
            prelen = len(questions)
            labels = dict()
            number = 0
            for label in questions:
                    if int(label['image_id']) in ids:
                        labels.update({number: label}) 
                        number += 1
            print(f'{len(labels)} remaining questions of {prelen} in {file}')
            data['questions'] = labels
            with open(out_qst_pth + '\\' + file, 'w') as f:
                json.dump(data, f)

def main():
    img_pth = out_img_pth
    annot_pth = ann_pth
    quest_pth = qst_pth
    removing(img_pth, annot_pth, quest_pth)
    
main()
# Out:
# 3000 remaining annotations of 60000 in ann_train.json
# 1500 remaining annotations of 30000 in ann_val.json
# 3000 remaining questions of 60000 in multi_qst_test.json
# 3000 remaining questions of 60000 in open_qst_test.json
# 3000 remaining questions of 60000 in multi_qst_train.json
# 3000 remaining questions of 60000 in open_qst_train.json
# 1500 remaining questions of 30000 in multi_qst_val.json
# 1500 remaining questions of 30000 in open_qst_val.json

# %% [markdown]
# Make vocab

# %%
def make_q_vocab(input_dir, output_dir):

    for file in os.scandir(input_dir):
        if "test" in file.name:
            continue
        if not os.path.exists(output_dir):
            os.makedirs(output_dir) 
            
        regex = re.compile(r'(\W+)')
        q_vocab = []
        path = os.path.join(input_dir, file.name)
        with open(path, 'r') as f:
            q_data = json.load(f)
        question = q_data['questions'].values()
        for quest in question:
            split = regex.split(quest['question'].lower())
            tmp = [w.strip() for w in split if len(w.strip()) > 0]
            q_vocab.extend(tmp)
    
        q_vocab = list(set(q_vocab))
        q_vocab.sort()
        q_vocab.insert(0, '<pad>')
        q_vocab.insert(1, '<unk>')
    
        with open(output_dir + '\\' + file.name.split(".")[0] + '_vocabs.txt', 'w') as f:
            f.writelines([v+'\n' for v in q_vocab])

        print(f'The number of total words of questions in {file.name}: {len(q_vocab)}')

def make_a_vocab(input_dir, output_dir):

    for file in os.scandir(input_dir):
        if not os.path.exists(output_dir):
            os.makedirs(output_dir) 
            
        answers = defaultdict(lambda :0)
        path = os.path.join(input_dir, file.name)
        with open(path, 'r') as f:
            data = json.load(f)
        annotations = data['annotations'].values()
        for label in annotations:
            for ans in label['answers']:
                vocab = ans['answer']
                if re.search(r'[^\w\s]', vocab):
                    continue
                answers[vocab] += 1
    
        answers = sorted(answers, key=answers.get, reverse= True) 
        with open(output_dir + '\\' + file.name.split(".")[0] + '_vocabs.txt', 'w') as f :
            f.writelines([ans+'\n' for ans in answers])
            
        print(f'The number of total words of answers in {file.name}: {len(answers)}')

def make_vocab(output_dir):
    ann_vocab = set()
    qst_vocab = set()
    for file in os.scandir(output_dir):
        if 'ann' in file.name:
            with open(file.path, 'r') as f:
                for line in f: 
                    print(line)
                    ann_vocab.add(line.split('\n')[0])
        elif 'qst' in file.name:
            with open(file.path, 'r') as f:
                for line in f: 
                    qst_vocab.add(line.split('\n')[0])

    print(ann_vocab)
    print(f'The number of total words of answers in ann_vocabs will be: {len(ann_vocab)}')
    print(f'The number of total words of answers in qst_vocabs will be: {len(qst_vocab)}')
    
    with open(output_dir + '\\ann_vocabs.txt', 'w') as f:
        f.writelines([ans+'\n' for ans in ann_vocab])
    with open(output_dir + '\\qst_vocabs.txt', 'w') as f:
        f.writelines([ans+'\n' for ans in qst_vocab])

def main():
    input_qst_dir = out_qst_pth
    input_ann_dir = out_ann_pth
    output_vocab_dir = out_vocab_pth
    make_q_vocab(input_qst_dir, output_vocab_dir)
    make_a_vocab(input_ann_dir, output_vocab_dir)
    make_vocab(out_vocab_pth)
main()
# Out:
# The number of total words of questions in multi_qst_train.json: 1283
# The number of total words of questions in multi_qst_val.json: 937
# The number of total words of questions in open_qst_train.json: 1283
# The number of total words of questions in open_qst_val.json: 937
# The number of total words of answers in ann_train.json: 2131
# The number of total words of answers in ann_val.json: 1288
# yes
#
# no
#
# 2
#
# 1
#
# 3
#
# red
#
# 4
#
# dog
#
# white
#
# brown
#
# blue
#
# yellow
#
# cat
#
# 0
#
# green
#
# soccer
#
# sitting
#
# 5
#
# girl
#
# right
#
# table
#
# gray
#
# floor
#
# log
#
# bench
#
# tan
#
# wine
#
# black
#
# skateboard
#
# playing
#
# football
#
# sunny
#
# man
#
# orange
#
# duck
#
# woman
#
# sleeping
#
# monkey bars
#
# no one
#
# rug
#
# bone
#
# baseball
#
# couch
#
# yarn
#
# blanket
#
# bird
#
# mouse
#
# chair
#
# plant
#
# book
#
# grass
#
# tree
#
# boy
#
# beehive
#
# fish
#
# stool
#
# nothing
#
# jumping
#
# standing
#
# pie
#
# sun
#
# left
#
# food
#
# pond
#
# bush
#
# sandbox
#
# picnic
#
# baby
#
# cloud
#
# toys
#
# sand
#
# bike
#
# sidewalk
#
# maybe
#
# jump rope
#
# on table
#
# slide
#
# sunset
#
# beige
#
# owl
#
# dollhouse
#
# on blanket
#
# tv
#
# deer
#
# soccer ball
#
# pizza
#
# happy
#
# picture
#
# sky
#
# steak
#
# birds
#
# apple
#
# watermelon
#
# ball
#
# blocks
#
# bees
#
# walking
#
# day
#
# dancing
#
# on floor
#
# sandwich
#
# pink
#
# eating
#
# running
#
# turtle
#
# park
#
# 6
#
# flowers
#
# bicycle
#
# waving
#
# bread
#
# fireplace
#
# abcd
#
# nobody
#
# ground
#
# 8
#
# wall
#
# jumping rope
#
# wood
#
# hot dog
#
# bear
#
# bat
#
# reading
#
# on couch
#
# tea
#
# outside
#
# raccoon
#
# bottle
#
# watching tv
#
# lady
#
# coat rack
#
# painting
#
# floral
#
# logs
#
# squirrel
#
# rabbit
#
# 10
#
# laughing
#
# pigtails
#
# ribs
#
# wine bottle
#
# marshmallows
#
# playing with dog
#
# mushroom
#
# sandwiches
#
# basket
#
# grill
#
# round
#
# grilling
#
# turtles
#
# none
#
# pillow
#
# tongs
#
# teddy bear
#
# on right
#
# picnic basket
#
# robot
#
# on wall
#
# on grass
#
# gold
#
# 7
#
# on rug
#
# red and white
#
# petting cat
#
# fire
#
# in sky
#
# under tree
#
# bed
#
# cup
#
# in pond
#
# hands
#
# cold
#
# on stool
#
# middle
#
# ball of yarn
#
# meat
#
# eagle
#
# fringe
#
# by tree
#
# friends
#
# steaks
#
# on ground
#
# coats
#
# kickstand
#
# head
#
# living room
#
# old
#
# trees
#
# sitting on bench
#
# ducks
#
# fish and duck
#
# night
#
# shovel
#
# pet
#
# hot
#
# toy
#
# coat
#
# purple
#
# sunrise
#
# dog bed
#
# laying down
#
# mushrooms
#
# legos
#
# camera
#
# clouds
#
# above fireplace
#
# bucket
#
# lunch
#
# grandma
#
# carpet
#
# inside
#
# rocks
#
# under table
#
# moon
#
# mice
#
# ponytail
#
# helmet
#
# doll
#
# pine
#
# frog
#
# on bench
#
# 18
#
# d
#
# scooter
#
# frisbee
#
# brunette
#
# sunglasses
#
# sliding
#
# rose
#
# swimming
#
# bare
#
# chasing mouse
#
# square
#
# long
#
# ottoman
#
# sofa
#
# unknown
#
# glass
#
# holding it
#
# lily pads
#
# cats
#
# fall
#
# horse
#
# in tree
#
# full grown
#
# eggs
#
# warm
#
# asleep
#
# coffee table
#
# dinner
#
# center
#
# pug
#
# pail
#
# flying
#
# bars
#
# red and gold
#
# nowhere
#
# pet bed
#
# sad
#
# leg
#
# resting
#
# flower
#
# right one
#
# rat
#
# cake
#
# lasagna
#
# eat
#
# 15
#
# in fireplace
#
# plain
#
# apples
#
# rectangle
#
# rocking horse
#
# little girl
#
# possibly
#
# picnic blanket
#
# potted plant
#
# on chair
#
# child
#
# wine glass
#
# balancing
#
# after
#
# stuffed animal
#
# fun
#
# clear
#
# hive
#
# tired
#
# holding
#
# curly
#
# cool
#
# puppies
#
# seesaw
#
# blonde
#
# right side
#
# toast
#
# lap
#
# partly cloudy
#
# chihuahua
#
# under bench
#
# left side
#
# coat hanger
#
# window
#
# old woman
#
# my best guess is no
#
# golden
#
# koi
#
# chilly
#
# playing with blocks
#
# on sofa
#
# maroon
#
# cloth
#
# couches
#
# v
#
# cloudy
#
# cat and dog
#
# tea set
#
# black and gray
#
# watching
#
# playing with cat
#
# pointing
#
# chicken
#
# nest
#
# footstool
#
# talking
#
# cheese
#
# not sure
#
# black and white
#
# red and gray
#
# books
#
# dog chasing cat
#
# shelf
#
# grandmother
#
# chipmunks
#
# girls
#
# nice
#
# puppy
#
# casual
#
# ants
#
# corn
#
# behind couch
#
# on picnic blanket
#
# car
#
# jungle gym
#
# one on right
#
# champagne
#
# marshmallow
#
# no dog
#
# climbing
#
# next to girl
#
# 30
#
# box
#
# cd
#
# kitten
#
# old man
#
# go down
#
# video game
#
# on sidewalk
#
# yellow and white
#
# petting dog
#
# plate
#
# feed duck
#
# moped
#
# homework
#
# 70
#
# on fireplace
#
# daisy
#
# begging
#
# home
#
# on slide
#
# next to tree
#
# serving tea
#
# brown and green
#
# kicking soccer ball
#
# wine bottles
#
# behind cloud
#
# crying
#
# drapes
#
# curtains
#
# pictures
#
# picking flowers
#
# picnic baskets
#
# doormat
#
# tan and white
#
# to right
#
# scratching
#
# stretching
#
# on ottoman
#
# jump roping
#
# light blue
#
# old lady
#
# on coffee table
#
# goldfish
#
# smiling
#
# next to sandbox
#
# glass of wine
#
# holding hands
#
# baked
#
# bikes
#
# orange and black
#
# both
#
# frame
#
# chairs
#
# morning
#
# throwing it
#
# no idea
#
# person
#
# in pet bed
#
# standing on log
#
# many
#
# can
#
# on shelf
#
# lying down
#
# 20
#
# lots
#
# pizza and salad
#
# birds and butterflies
#
# hanging
#
# boy and girl
#
# television
#
# flowered
#
# plate of food
#
# people
#
# yoga
#
# b c d
#
# to left
#
# slide and monkey bars
#
# cooking
#
# relaxing
#
# putting it back
#
# holding book
#
# winter
#
# balance
#
# air
#
# portrait
#
# tassels
#
# no table
#
# dandelions
#
# warming hands
#
# under window
#
# in front of couch
#
# burger
#
# touching bookcase
#
# hamburger
#
# doll and teddy bear
#
# bookshelf
#
# neither
#
# covering eyes
#
# wine glasses
#
# bee
#
# eye
#
# mantle
#
# butterflies
#
# paintings
#
# there is no cat
#
# pail and shovel
#
# no knife
#
# shrub
#
# lonely
#
# window sill
#
# paper
#
# bucket and sun
#
# ant
#
# herself
#
# slipper
#
# to get warm
#
# unsure
#
# 9
#
# in living room
#
# in front of sofa
#
# monkey bar
#
# toy car
#
# gone
#
# redhead
#
# daytime
#
# fair
#
# sitting on log
#
# dolls
#
# laying
#
# water
#
# bottom right
#
# 40
#
# petting
#
# evergreen
#
# her dog
#
# plant and coat rack
#
# above couch
#
# cartoons
#
# bbq
#
# swinging
#
# male and female
#
# behind man
#
# flowery
#
# tablecloth
#
# boys
#
# man and woman
#
# mother
#
# mom
#
# exercising
#
# in middle
#
# throwing
#
# on log
#
# most of it
#
# broke
#
# above it
#
# on mantel
#
# hot dogs
#
# very
#
# putting back
#
# 60
#
# on sandbox
#
# leaves
#
# on horizon
#
# playing on monkey bars
#
# armchair
#
# chocolate
#
# to eat
#
# eating pie
#
# fall over
#
# between windows
#
# by sidewalk
#
# squirrels
#
# standing on hind legs
#
# on arm of chair
#
# next to couch
#
# dog is chasing cat
#
# reaching
#
# dog jumping off couch
#
# bookcase
#
# in its bed
#
# butterfly
#
# chasing her
#
# hawk
#
# covering her eyes
#
# grandpa and granddaughter
#
# barbecuing
#
# boy and dog
#
# dog on right
#
# nose
#
# goose
#
# in sandbox
#
# blocks and legos
#
# on boys lap
#
# baseball bat
#
# same amount
#
# double doors
#
# afraid
#
# burn
#
# fish and lily pads
#
# welcome mat
#
# dessert
#
# sundae
#
# brown and white
#
# orange and white
#
# bucket and shovel
#
# shovel and bucket
#
# waiting
#
# in grass
#
# bouncing
#
# by pond
#
# ficus
#
# fern
#
# poodle
#
# no one else is home
#
# es
#
# robot and dollhouse
#
# robot and doll house
#
# warmth
#
# to keep warm
#
# party
#
# for football
#
# playing catch
#
# poor design
#
# stepping on it
#
# walking on it
#
# standing on it
#
# kicking
#
# against tree
#
# back of chair
#
# on armchair
#
# mosquito
#
# picnicking
#
# behind sofa
#
# holding them out
#
# to stay warm
#
# off white
#
# shish kabob
#
# before
#
# being petted
#
# another room
#
# older
#
# fabric
#
# triangle
#
# dog on table
#
# noon
#
# yes and no
#
# roasting it
#
# roasting
#
# middle of room
#
# yellow cat
#
# partly
#
# field
#
# in bed
#
# eating nut
#
# red white
#
# playhouse
#
# play house
#
# upright
#
# down
#
# forward
#
# joke
#
# dog and cat
#
# cat dog
#
# drink
#
# on monkey bars
#
# playing in sand
#
# in girls hand
#
# hand
#
# stuffed animals
#
# blue and black
#
# fishing pole
#
# shoes
#
# friend
#
# 35
#
# lot
#
# no coat
#
# in front of tree
#
# playing jump rope
#
# to go down
#
# to slide
#
# she likes it
#
# person on right
#
# boy on right
#
# fir
#
# pine tree
#
# n
#
# boy in black
#
# tv show
#
# woman is holding it
#
# it will go down
#
# to eat cheese
#
# game console
#
# movie
#
# fire and logs
#
# yellow and black
#
# walking his dog
#
# on footrest
#
# no tile
#
# toy robot
#
# to play with dog
#
# life
#
# spaghetti
#
# snacks
#
# forks
#
# stuff
#
# fork
#
# plates
#
# woman and boy
#
# in dog bed
#
# adult
#
# woman in white shirt
#
# older woman
#
# to feed duck
#
# park bench
#
# lower right
#
# bottom right corner
#
# red and white checkered
#
# beautiful
#
# turkey
#
# 12
#
# messy
#
# new
#
# kittens
#
# out
#
# by couch
#
# jump
#
# most
#
# sitting on couch
#
# side by side
#
# chips
#
# above
#
# reach nest
#
# very hot
#
# oval
#
# having fun
#
# to play
#
# burgundy
#
# riding bike
#
# putting book on shelf
#
# cups and wine bottle
#
# senior
#
# playing with plant
#
# ties
#
# toys on rug
#
# disc
#
# fringes
#
# no tv stand
#
# mantel
#
# on top of fireplace
#
# getting petted
#
# under right window
#
# scratching chair
#
# bunny
#
# for picnic
#
# birthday
#
# on her neck
#
# neck
#
# looking for food
#
# toward pond
#
# near sidewalk
#
# beside sidewalk
#
# front of couch
#
# cat made mess
#
# mess on floor
#
# mess
#
# burger and hot dog
#
# arm of couch
#
# chopped down
#
# grill lid
#
# next to fireplace
#
# beside fireplace
#
# stuffed toy
#
# dog jumping
#
# in table
#
# kid
#
# doll and cat
#
# in park
#
# with woman
#
# 16
#
# 11
#
# 14
#
# at
#
# letters
#
# kids
#
# on tree
#
# daisies
#
# dandelion
#
# tray
#
# sprinkler
#
# disco
#
# scared
#
# short
#
# christmas
#
# no friends
#
# playing soccer
#
# kicking ball
#
# ay
#
# head and shoulders
#
# rectangular
#
# in between
#
# reaching for wine bottle
#
# in middle of logs
#
# between logs
#
# see saw
#
# standing on see saw
#
# in front of window
#
# for cat
#
# beside window
#
# red book
#
# teenage boy
#
# date
#
# boys lap
#
# sticks
#
# toy horse
#
# dollhouse and blocks
#
# same
#
# under picture
#
# underpainting
#
# waiting for ball
#
# tables
#
# double
#
# red one
#
# watching bunny
#
# jogging
#
# oak
#
# apple tree
#
# melt
#
# have picnic
#
# tv stand
#
# dbca
#
# long pants
#
# brown and purple
#
# mat
#
# teddy bear and robot
#
# ice cream
#
# cupcake
#
# banana split
#
# desert
#
# blue chair
#
# toy shovel and toy bucket
#
# melon
#
# no knife available to cut it
#
# waiting for company
#
# some is
#
# because it is whole
#
# very right
#
# climbing chair
#
# jumping towards woman
#
# peanut butter bread
#
# young girl
#
# his lap
#
# sunny with clouds
#
# near blanket
#
# on mat
#
# leafy plant
#
# green plant
#
# visa
#
# potted bush
#
# indoor plant
#
# chiwawa
#
# she is home alone
#
# everyone else left
#
# spinster
#
# she is single
#
# because she got home early
#
# shirt and pants
#
# long sleeves
#
# sweater and pants
#
# classy
#
# sweater
#
# 4 each
#
# dollhouse and robot
#
# toy robot and tiny house
#
# pot with plant
#
# lady is sitting at table
#
# argument
#
# not having tv
#
# his wife
#
# his age
#
# unclear
#
# seat
#
# ladies feet
#
# below bench
#
# underneath park bench
#
# people were sitting there
#
# viewing
#
# to sit on
#
# left there
#
# storytime
#
# in center of picture
#
# on back wall
#
# by wall
#
# middle of road
#
# by cat bed
#
# in room
#
# kitchen
#
# by window
#
# near wall
#
# picnic foods
#
# food and drinks
#
# pie wine and watermelon
#
# windowsill
#
# window seal
#
# they are playing football
#
# playing football
#
# get ball
#
# invisible steps
#
# bad work
#
# special design
#
# bad architecture
#
# step
#
# it floating
#
# mistake
#
# to keep dirt out
#
# blue and white
#
# notepad
#
# tv remote
#
# notebook
#
# sun and bucket
#
# skipping rope
#
# balancing on it
#
# jumping over it
#
# chipmunk
#
# rode bike
#
# on her bike
#
# behind monkey bar
#
# top left corner
#
# top left
#
# left corner
#
# wasps
#
# on back of chair
#
# boy in white shirt
#
# boy in white
#
# tilapia
#
# having picnic
#
# giggling
#
# park setting
#
# by sand box
#
# beside sandbox
#
# by sandbox
#
# teal
#
# so far sofa
#
# stand
#
# piece of corn
#
# dog has something
#
# dog has his shoe
#
# dog has slipper
#
# dog eating corn
#
# dog eating shoe
#
# dog is misbehaving
#
# dog has shoe
#
# back of couch
#
# guy
#
# her friend
#
# behind woman
#
# by lady
#
# behind tv
#
# holding out
#
# spreading
#
# waving them
#
# opening them
#
# concert
#
# flying in sky
#
# in air
#
# brownish red
#
# no she is sitting closer to middle
#
# eating pizza
#
# sitting down to eat
#
# having meal
#
# sitting at table
#
# s
#
# getting warm
#
# warming up
#
# what is dog doing
#
# art
#
# on their bikes
#
# by bike
#
# bicycles
#
# playing blocks
#
# it is brown
#
# in front of fireplace
#
# den
#
# walking in living room
#
# front of fireplace
#
# wood and iron
#
# lot to cook
#
# barbecue
#
# lots of people coming
#
# lots of food to cook
#
# one for each meat
#
# cooking on each
#
# they love grilling
#
# different food
#
# different types of food
#
# after summer
#
# walking towards him
#
# wanting attention
#
# walking towards boy
#
# truck
#
# toy truck
#
# she has more toys
#
# less toys
#
# because he is hungry
#
# bullying
#
# he is bored
#
# interesting things
#
# playing at park
#
# tail
#
# girl smiling
#
# it looks happy
#
# its running around
#
# tail vertical
#
# left sofa
#
# woman is
#
# she is sitting near cat
#
# sitting sideways
#
# skateboarding baseball soccer
#
# soccer baseball skateboarding
#
# soccer baseball and skateboard
#
# climber
#
# sandbox and monkey bars
#
# seesaw and sandbox
#
# in another room
#
# in other room
#
# there is none
#
# blue cloth
#
# white cloth
#
# bushes
#
# coat stand
#
# taller girl
#
# yes he does
#
# white wine
#
# upside down v
#
# arrow
#
# stuffed cat
#
# boy and dog on table
#
# boy and dog on bench
#
# boy petting dog
#
# boy on table
#
# him standing on bench
#
# dog and boy on table
#
# daylight
#
# high noon
#
# to play with yarn
#
# to get yarn
#
# watermelons on right
#
# it was white bone dog likes bones
#
# handlebars
#
# crossing bars
#
# melting it
#
# heating over fire
#
# heating
#
# roasting them
#
# left hand
#
# dining room
#
# middle room
#
# dog park
#
# fowl
#
# dog and bird
#
# clear and sunny
#
# brown dog
#
# other cat
#
# sleeping cat
#
# white kitten
#
# brown cat
#
# saying stop
#
# attention
#
# preventing baby from eating sand
#
# keep it from eating sand
#
# pick up baby
#
# he likes him
#
# help
#
# to grab him
#
# kid and bucket
#
# boy and bucket
#
# child and pail
#
# mountain ridge
#
# landscape
#
# sunset behind rolling hills
#
# lavender
#
# cement
#
# man is about to ride bike
#
# at park
#
# sleeping in his bed
#
# on bed
#
# in his bed
#
# in its dog bed
#
# his bed
#
# its bed
#
# sitting between flowers and mushrooms
#
# seeing flower
#
# about to go on monkey bars
#
# playing with her dog
#
# scratching tree and sitting on log
#
# sniffing
#
# cat is sleeping in chair
#
# toy house
#
# beside child
#
# next to little boy
#
# bush and mushroom
#
# shrub and grass
#
# nightshade
#
# sisters
#
# apple pie
#
# picnic food
#
# 200
#
# jungle jim
#
# himself
#
# sitting on chair
#
# sitting up straight
#
# center of couch
#
# slanted
#
# crossed legs
#
# prone
#
# upright sitting position
#
# books on shelf
#
# she fell off couch
#
# messy bookcase
#
# books falling off shelf
#
# comedy
#
# cats and dogs
#
# 3 months
#
# color of ladies pant is brown
#
# climbing device
#
# taupe
#
# gym equipment
#
# hanging from monkey bars
#
# to use in sandbox
#
# 1 is
#
# her hand
#
# girl has it
#
# dolls and rocking horse
#
# doll and tea set
#
# girl toys
#
# 4q
#
# red bag
#
# soda
#
# legs
#
# her left leg
#
# toddler
#
# calling boy
#
# feet
#
# girlfriend
#
# 25
#
# salad and pizza
#
# pizza salad
#
# sitting on grass
#
# catching something
#
# holding arm up
#
# there are mice
#
# rats
#
# indoors
#
# by yarn ball
#
# front of tree
#
# on far right in front of tree
#
# skipping
#
# sliding onto picnic blanket
#
# for sliding
#
# obviously idea is to slide down it
#
# use
#
# to exit on to grass
#
# jumping up
#
# on loveseat
#
# braids
#
# ponytails
#
# bread sticks
#
# breadsticks
#
# playing with her cat
#
# it is tired from playing with yarn
#
# it likes her
#
# likes girl
#
# for comfort
#
# kneeling
#
# kneeling down
#
# looking at it
#
# sun water and sand
#
# man on right
#
# 44
#
# spruce
#
# older man
#
# grandpa
#
# boy on left
#
# boy left
#
# left boy
#
# black shirt guy
#
# white guy with black hair
#
# soup and pork chops
#
# breakfast
#
# soup
#
# soup and bread
#
# football and birds and butterflies
#
# orange and blue
#
# family
#
# modern
#
# woman fell
#
# pets
#
# animals
#
# under woman
#
# girls hand
#
# in girls hands
#
# held by women
#
# frogs
#
# lillys
#
# water lilies
#
# bees heading toward dog
#
# dog chasing butterflies
#
# it will drop
#
# will go down
#
# to get cheese
#
# after food
#
# get food
#
# cat eating
#
# eat cheese
#
# over couch
#
# above sofa
#
# near
#
# phone
#
# gaming console
#
# wii
#
# show
#
# blank screen
#
# cuba
#
# g c b
#
# abc
#
# does boy know that there is mouse in house
#
# girl in blue
#
# right chair
#
# someone is going to drink it
#
# to drink
#
# waiting to be drunk
#
# to wait
#
# person put it there
#
# someone was sitting in chair
#
# someone will drink it
#
# clouds are in front of sun
#
# on pavement
#
# walking on sidewalk
#
# walking on path
#
# tv is funny
#
# something funny is on tv
#
# funny show
#
# television is amusing
#
# funny tv show
#
# watching television
#
# at television
#
# no is my best guess
#
# setting
#
# she sits
#
# no it is not safe
#
# male female
#
# on ground by pond
#
# behind boy
#
# on ground behind man
#
# lego bricks
#
# walking with dog
#
# playing with his dog
#
# walking dog
#
# meeting woman
#
# red and orange
#
# on foot stool
#
# on footstool
#
# coffee
#
# fruits
#
# wicker picnic
#
# curtain
#
# robot toy
#
# boy is holding toy
#
# fishes
#
# to pick dog
#
# poly with dog
#
# play with dog
#
# balanced
#
# pedal
#
# leaning on stand
#
# on his bicycle
#
# where is girl
#
# pointing at cat
#
# sitting together in park
#
# feeding fish
#
# watching fish in pond
#
# looking at pond
#
# watching fishes in pond
#
# koy
#
# something serious
#
# dollar bill
#
# smores
#
# plates and silverware
#
# table needs silverware for women to eat dessert
#
# napkins
#
# space
#
# couple
#
# parents
#
# man woman
#
# watching turtle
#
# circular
#
# between people
#
# underneath table
#
# plates on table
#
# on plates
#
# oldest
#
# solitude
#
# animal is duck
#
# for bird
#
# to feed ducks
#
# feed ducks
#
# eat it
#
# get food with his hands
#
# grab
#
# peanut butter toast
#
# at home
#
# not here
#
# she is not sleeping
#
# next to grass
#
# park right side
#
# standing on 1 leg
#
# aerobics
#
# checkered
#
# woman on right
#
# taller one
#
# woman in white
#
# spaghetti with meatballs
#
# thinking
#
# just sitting on couch
#
# wicker
#
# grape
#
# it looks curly
#
# o
#
# little
#
# jumping on sofa
#
# jumping on couch
#
# d b c
#
# brown with white tablecloth
#
# wine and sandwich
#
# few years
#
# 2 years
#
# 3 years
#
# 10 years
#
# 2 years old
#
# what is in tree
#
# waiving
#
# waving hand
#
# grilling food
#
# that is butterfly
#
# not in room
#
# other room
#
# they went out somewhere
#
# away
#
# between desk and sofa
#
# left of couch
#
# light pink
#
# under couple
#
# underneath
#
# duck and bird
#
# 3 birds
#
# juice
#
# lines
#
# stripes
#
# stripes with circle
#
# next to pond
#
# beside pond
#
# center of picture
#
# near pond
#
# in middle of picture
#
# sitting on scooter
#
# mope head
#
# yes he is
#
# poor decor
#
# artistic style
#
# short person hung it
#
# hung that way
#
# looks nice
#
# decor
#
# so cat can be seen
#
# owner put it there
#
# misplaced
#
# throwing ball
#
# throwing it to boy
#
# tossing it
#
# monkey stand
#
# slide and jungle jim
#
# duck and fish
#
# bald eagle
#
# crow
#
# glass of wine and book
#
# book glass
#
# book and wine
#
# glass scissors book
#
# mostly
#
# almost all of it
#
# almost all
#
# cat toy
#
# being curious
#
# looking at deserts
#
# standing on hind legs with front paws on table
#
# leaping
#
# pouncing
#
# trying to get food
#
# chasing dog
#
# roasted marshmallows
#
# shooing away mouse
#
# freaking out
#
# staying away from mouse
#
# filling it with sand
#
# taking it
#
# filling
#
# filling sand
#
# playing with sand
#
# playing game
#
# building with blocks
#
# playing on floor with blocks
#
# close to each other
#
# close to one another
#
# skewed
#
# two
#
# next to each other
#
# uneven
#
# one higher
#
# one higher than other
#
# chips and salsa
#
# nachos
#
# chips and dip
#
# sold
#
# someone sold it
#
# woman sold it
#
# donated to charity
#
# it broke
#
# green brown
#
# black white
#
# white and black
#
# not clear
#
# background
#
# top of picture
#
# string
#
# cooking ribs to be eaten by people when they sit on blanket
#
# cook
#
# to cook food
#
# to cook food for picnic
#
# cooking food
#
# higher
#
# behind
#
# above and behind it
#
# rope
#
# to look at nest
#
# feed birds
#
# to see nest
#
# to reach nest
#
# putting nest back in tree
#
# picking apples
#
# reach bird nest
#
# baby robins
#
# duck and fishes
#
# reptiles
#
# somewhat
#
# 5000c
#
# really hot
#
# 78 degrees
#
# to get dog
#
# picking up dog
#
# grabbing bone
#
# dancing with bone
#
# playing with girl
#
# holding bone for dog
#
# giving dog bone
#
# playing with bone
#
# giving bone
#
# prancing
#
# color of cat is yellow
#
# picking it up
#
# sitting with books
#
# red and purple
#
# red black white
#
# red and silver
#
# red and blue
#
# he is trying to catch frisbee
#
# sitting down
#
# her left
#
# road her bike
#
# sleepy
#
# because she rode bike
#
# she rode to park
#
# from riding
#
# cycling
#
# long bike ride
#
# taking it out
#
# back
#
# put it back
#
# carrying book
#
# getting books
#
# cleaning
#
# cups and wine
#
# wine and cups
#
# coats and hats
#
# 65
#
# 55
#
# middle age
#
# 85
#
# 80
#
# trying to grab plant
#
# messing with plant
#
# climbing to plant
#
# on edge of sandbox
#
# blinds
#
# rings
#
# knot
#
# curtain ties
#
# tie back
#
# tie backs
#
# ribbons
#
# bread crumb
#
# there is no dog
#
# in front of cat
#
# mad
#
# hug
#
# reaching for dad
#
# to balance
#
# asking question
#
# he wants to be picked up
#
# liquid
#
# white and red
#
# right of children
#
# toys and camera
#
# train
#
# next to boy
#
# woman and food
#
# cheese and steak
#
# plate teak and some cheese
#
# cd disk
#
# disk
#
# dvd
#
# bird nest
#
# branch
#
# towards boy
#
# toward boy
#
# east
#
# towards man
#
# northeast
#
# tree by see saw
#
# path
#
# pyramids
#
# dad
#
# no vase
#
# table behind little girl
#
# my best guess is none
#
# roses
#
# no flowers
#
# pretty
#
# green apple
#
# no clouds
#
# to right of window
#
# right of sofa
#
# next to sofa
#
# right of couch
#
# on right of couch
#
# fray
#
# tassel
#
# wool
#
# woman is jumping rope
#
# corner of blanket
#
# violet
#
# sleeping on couch
#
# drinking
#
# no table for it
#
# table broke
#
# no stand
#
# on blue stool
#
# white and gray
#
# cotton
#
# weeds
#
# what is man doing
#
# i can see turtles in water
#
# horizon
#
# on frame
#
# in center
#
# in both
#
# in pictures
#
# friendly
#
# love each other
#
# like
#
# love
#
# they are friendly
#
# like each other
#
# good
#
# red brown
#
# wants to eat it
#
# dogs like bones
#
# to eat it
#
# he wants bone
#
# considering to eat it
#
# dog wants bone
#
# hungry
#
# wants it
#
# rope jumper caught his attention
#
# it wants treat
#
# he wants to play
#
# because boy is jumping
#
# getting boys attention
#
# it is excited
#
# climbing monkey bars
#
# warming by fire
#
# warming himself
#
# holding out his hands
#
# warming his hands over fire
#
# get up off floor
#
# good morning
#
# love you
#
# behave
#
# get up
#
# she is cute
#
# hello
#
# good job
#
# what are you playing
#
# standing next to girl
#
# standing by woman
#
# middle of floor
#
# on carpet
#
# watching cat chase mouse
#
# gray and red
#
# by coat rack
#
# floor by coat rack
#
# trying to get on couch
#
# clawing
#
# dumb
#
# reading book
#
# sitting with book
#
# down sidewalk
#
# towards viewer
#
# yes it is
#
# on coat rack
#
# on rack
#
# rack
#
# playing kickball
#
# kickball
#
# striking pose
#
# scared of mice
#
# being afraid of mice
#
# saluting
#
# computer
#
# yellow books
#
# winning lotto
#
# they won lottery
#
# winning lottery
#
# retirement
#
# friday night
#
# basket wine burger
#
# basket hamburger wine
#
# picnic basket and food
#
# basket and food
#
# picnic lunch
#
# beside left tree
#
# rode scooter
#
# on scooter
#
# motorcycle
#
# watching dog
#
# chatting
#
# by her neck
#
# surprise
#
# they are after food
#
# looking for cheese
#
# orange red
#
# brown seat
#
# recliner
#
# blueberry
#
# it appears to be pie
#
# pumpkin
#
# plenty for everyone
#
# 1 for each of people sitting
#
# there are 2 people
#
# for each person
#
# to be eaten
#
# enjoying their time together
#
# having pie
#
# it will fall over
#
# it will get knocked over
#
# get knocked over
#
# tea party
#
# serving
#
# setting table
#
# carrying teapot
#
# carrying tray
#
# above woman
#
# elderly
#
# 45
#
# 50
#
# teetering
#
# seesawing
#
# play with
#
# waiting for its parents
#
# sitting on it
#
# north
#
# west
#
# up
#
# to pond
#
# front right
#
# next to sidewalk
#
# under
#
# red and burgundy
#
# blue stuffed animal
#
# small doll
#
# blue one
#
# blue dog
#
# barbie doll
#
# blue bear
#
# blonde one
#
# ducks and bluebird
#
# various
#
# by and in pond
#
# at pond
#
# mid right
#
# in and near pond
#
# too much wine
#
# most likely
#
# cat knocked stuff down
#
# room is mess
#
# there is mess
#
# basket tablecloth people
#
# bbq grill
#
# small
#
# bulldog
#
# hamburgers
#
# steak and hot dog
#
# arm
#
# on sofa arm
#
# couch arm
#
# on arm of couch
#
# couch handle
#
# arm of sofa
#
# armrest
#
# mp
#
# in middle of room
#
# on coach
#
# other pillow
#
# arm of chair
#
# likes to
#
# day off
#
# on center table
#
# cut down
#
# it became logs
#
# fell
#
# it blew away
#
# it was cut down
#
# fell down
#
# fall down
#
# wind knocked over
#
# touching bookshelves
#
# touching shelves
#
# touching bookshelf
#
# there is bug on ground
#
# giving her marshmallow
#
# my best guess is to show her something
#
# laughing at her
#
# she wants her hot dogs
#
# she has hot dog
#
# saw something funny
#
# bl
#
# browns
#
# standing on grass
#
# in grass to right of pond
#
# right of pond
#
# he was riding it
#
# he drove it there
#
# its parked
#
# parked
#
# to give person ride
#
# transportation
#
# main road it
#
# he rode it there
#
# it belongs to man
#
# red and black
#
# gray black
#
# black or gray
#
# gray or black
#
# beside girl
#
# rock pond
#
# pool
#
# on top of boy
#
# on floor with child
#
# playing with baby
#
# on baby
#
# on top of kid
#
# over boy
#
# on kid
#
# on top baby
#
# one on carpet and one next to carpet
#
# in house
#
# sitting on chair to right
#
# sitting on blue chair
#
# on blue chair
#
# stuffed cat and doll
#
# doll and stuffed animal
#
# bet
#
# in between red slide and brown tree
#
# between slide and tree
#
# inside fireplace
#
# cat and 2 pillows
#
# next to lady
#
# garden
#
# next to bushes
#
# most people would say kickstand
#
# it was balanced very well
#
# self
#
# in shelf
#
# these are cats not dogs
#
# near girl
#
# by girl
#
# burd
#
# stuffed bear
#
# sister
#
# chasing
#
# right of picture
#
# next to stool
#
# solid
#
# no style
#
# futbol
#
# tiredness
#
# because she had long day
#
# she is tired
#
# she finished her chores
#
# red orange yellow
#
# red brown and yellow
#
# gold orange red
#
# abdc
#
# nobody in this picture
#
# everyone
#
# their kids
#
# steaks get overcooked
#
# near beehive
#
# on left
#
# by hive
#
# hives
#
# mud
#
# green and brown
#
# partially
#
# tree is full grown
#
# on wall to right of window
#
# on right of wall
#
# by chair
#
# teapots
#
# tea service
#
# tea tray
#
# blue and brown
#
# middle of wall in row
#
# girl and boy
#
# there is no tv
#
# small dog
#
# toys books cd
#
# teddy bears and dvd
#
# items
#
# bump
#
# chicken dance
#
# breakdance
#
# playing around
#
# wants to get away from other dog
#
# stool is too high
#
# he is lonely
#
# it wants to
#
# annoyed
#
# alarmed
#
# bad
#
# angry
#
# worried
#
# terrified
#
# curled up asleep
#
# sleeping on side
#
# laying down sleeping
#
# yellow and gold
#
# between 2 trees
#
# to left of walkway
#
# keep warm
#
# weed
#
# tree and bush
#
# bush and evergreen
#
# mouses
#
# performing trick
#
# he sees bug in air
#
# support
#
# hiding eyes
#
# kitty
#
# 52
#
# 30 each
#
# drinks
#
# wine cups
#
# glasses
#
# cheering
#
# yes just different colors
#
# she likes solitude
#
# her friends left
#
# her parents are gone
#
# nobody to play with
#
# unlovable
#
# no one else is with her
#
# on seat
#
# he is hot
#
# heat
#
# animal
#
# soil
#
# behind bush
#
# old man and young girl
#
# girl and old man
#
# man and grand daughter
#
# man and child
#
# grandfather and granddaughter
#
# footrest
#
# on foot rest
#
# far right
#
# on right side
#
# glass of wine is next to cat
#
# barking
#
# sitting on arm of couch
#
# rode bicycle
#
# on bike
#
# sunny and clear
#
# sunny with cloud
#
# his right hand
#
# one is
#
# plate of pizza
#
# on park bench
#
# sausages
#
# on picnic spread
#
# cat and baby
#
# boy and pet
#
# baby and cat
#
# 32 each
#
# 28
#
# 100
#
# 79
#
# brown with white spots
#
# tan with white spots
#
# cheek
#
# check
#
# teeth
#
# in hall
#
# near picture
#
# pizza on table
#
# top
#
# upper
#
# head and left arm
#
# head and arm
#
# head neck and right arm
#
# older lady
#
# in between both
#
# between
#
# between two
#
# inside frame
#
# bottles
#
# 2 bottles of wine
#
# shovel and pail
#
# other dogs
#
# dog is looking at puppies
#
# small dogs
#
# on fireplace mantle
#
# forest
#
# near woman
#
# next to mom
#
# under mom
#
# by mother
#
# by mom
#
# flying duck
#
# nature
#
# lake
#
# dove
#
# seagull
#
# sliding down slide
#
# to have fun
#
# gravity
#
# to see if she can
#
# it is fun
#
# for fun
#
# person taking picture
#
# lower right corner
#
# right side of photo
#
# between hat stand and potted plant
#
# desk
#
# behind table
#
# partially behind cloud
#
# bottle of wine
#
# reaching for wine
#
# reaching for bottle
#
# bringing bottle to table
#
# reaching hand out
#
# left of middle
#
# middle of logs
#
# in fire pit
#
# sunny with some clouds
#
# teeter totter
#
# playing on teeter totter
#
# standing on seesaw
#
# grandchild
#
# under couch
#
# olive
#
# pants
#
# pants or sidewalk
#
# talented
#
# by squatting
#
# bending
#
# pretending
#
# he is bending down
#
# cat to play with
#
# kitten to play
#
# so cat can play with it
#
# for cat to play with
#
# grass under tree
#
# cat bed
#
# in cat bed
#
# kitty bed
#
# sun out
#
# plaid
#
# plants and fish
#
# fish and lilies
#
# there are fish
#
# sun and butterflies
#
# near window
#
# right of window
#
# on floor to right
#
# falcon
#
# happiness
#
# having fun with his cat
#
# boy is playing with animal
#
# chasing cat
#
# rd
#
# sunset photo
#
# on dinner table
#
# wave
#
# feeding birds
#
# covering his eyes
#
# honeycomb
#
# babysitter
#
# older boy
#
# father
#
# owk
#
# spending time
#
# promotion
#
# their engagement
#
# lost game
#
# he sad
#
# mad at boy
#
# boy is brat
#
# he wants chair and boy is in way
#
# he is not happy
#
# hold
#
# white and brown
#
# brown and black
#
# holding dog
#
# holding cat
#
# sitting on chair with cat
#
# skewers
#
# sticks with marshmallows
#
# marshmallows on sticks
#
# grandma and child
#
# female
#
# beside couch
#
# girl on floor
#
# house blocks
#
# blocks and doll house
#
# doll house and blocks
#
# right side of sky
#
# sees ball
#
# father is playing with him
#
# playing with man
#
# playing with dad
#
# evergreens
#
# noble fir
#
# girl running
#
# to
#
# green leaf
#
# ferns
#
# herb
#
# house plants
#
# potted
#
# there are two house plants around fireplace they look to be large green leafy plants
#
# young boy
#
# bees hive
#
# one on right one
#
# right lady
#
# red shirt
#
# right girl
#
# woman in red shirt
#
# women on right
#
# red white check
#
# equal
#
# admiring flowers
#
# sitting on ground
#
# there are none
#
# there are no seats
#
# log to right
#
# natural instincts
#
# to catch it
#
# because cats like to chase things
#
# to kill it
#
# wants to play with it
#
# dark red
#
# standing on blanket
#
# at wall
#
# floor under paintings
#
# bronze
#
# ginger
#
# jokes
#
# man standing at grill
#
# boys hands
#
# plushie
#
# by kid
#
# so dog has somewhere to sleep
#
# for it to sleep
#
# so he can lay in it
#
# sleep in
#
# to sleep in
#
# he sleeps there
#
# to sleep
#
# on tables either side of couch
#
# 2 plants on either side of window
#
# on little table
#
# on tables
#
# soffa
#
# yarn ball
#
# monkey b
#
# rungs
#
# watching boy
#
# eating on sofa
#
# wooden
#
# wooden brown doors
#
# french
#
# twin doors
#
# below window
#
# underneath window
#
# in corner
#
# red hardback
#
# encyclopedia
#
# bible
#
# hardcover
#
# cream
#
# talking to someone
#
# watching rabbit
#
# looking at rabbit
#
# pony
#
# purple horse
#
# children
#
# girl in gray shirt
#
# mo
#
# by fireplace
#
# by rubbing his hands
#
# in sky and tree
#
# flying and in tree
#
# right tree
#
# flying under tree
#
# flying back to hive
#
# attacking raccoon
#
# logs and fire
#
# walkway
#
# walking around instead
#
# drying off
#
# because it wants to
#
# next to bush
#
# near center of picture
#
# buch
#
# what is in sky
#
# become roasted
#
# they will roast
#
# they will be burned
#
# will melt
#
# left bush
#
# 24
#
# koi fish and lily pads
#
# lost
#
# lost one
#
# torn off
#
# fell out
#
# replaced with button
#
# came out
#
# poked out
#
# broken
#
# it got ripped out
#
# floral pattern
#
# pink flowers
#
# right in front
#
# television stand
#
# sk
#
# by 1
#
# near tree
#
# on woman
#
# with lady
#
# in lap
#
# on left of picture
#
# playing in sandbox
#
# yes
#
# no
#
# 2
#
# 1
#
# 3
#
# red
#
# white
#
# blue
#
# yellow
#
# 0
#
# dog
#
# 4
#
# brown
#
# 5
#
# bird
#
# log
#
# green
#
# cat
#
# sitting
#
# table
#
# plant
#
# soccer
#
# orange
#
# girl
#
# football
#
# nothing
#
# wine
#
# woman
#
# black
#
# tan
#
# right
#
# sleeping
#
# food
#
# rug
#
# fire
#
# picture
#
# red and white
#
# floor
#
# apple
#
# skateboard
#
# steak
#
# gray
#
# blocks
#
# baseball
#
# playing
#
# watermelon
#
# man
#
# slide
#
# tree
#
# tv
#
# soccer ball
#
# bench
#
# boy
#
# beehive
#
# raccoon
#
# flowers
#
# sand
#
# pond
#
# bone
#
# left
#
# checkered
#
# sidewalk
#
# sunny
#
# tongs
#
# eating
#
# dollhouse
#
# book
#
# butterfly
#
# couch
#
# cup
#
# doll
#
# waving
#
# fireplace
#
# old
#
# ball
#
# pink
#
# toys
#
# on rug
#
# deer
#
# baby
#
# 7
#
# moon
#
# frisbee
#
# walking
#
# black and white
#
# park
#
# pie
#
# sun
#
# turtle
#
# blanket
#
# sunset
#
# mouse
#
# beige
#
# steaks
#
# coat rack
#
# on floor
#
# mushroom
#
# chihuahua
#
# maybe
#
# seesaw
#
# painting
#
# basket
#
# dancing
#
# ground
#
# grass
#
# on table
#
# roasting marshmallows
#
# sky
#
# running
#
# chair
#
# scooter
#
# squirrel
#
# portrait
#
# outside
#
# wood
#
# monkey bars
#
# plate
#
# mother
#
# empty
#
# nest
#
# cloudy
#
# standing
#
# purple
#
# water
#
# dogs
#
# duck
#
# jump rope
#
# mice
#
# floral
#
# grill
#
# on grass
#
# picnic
#
# fish
#
# bees
#
# butterflies
#
# little girl
#
# meat
#
# see saw
#
# flower
#
# watching tv
#
# window
#
# swimming
#
# door
#
# robot
#
# real
#
# knife
#
# july
#
# blankets
#
# x
#
# cloud
#
# pillow
#
# closed
#
# jumping
#
# hide and seek
#
# 10
#
# marshmallows
#
# relaxing
#
# happy
#
# teddy bear
#
# 8
#
# young
#
# cheese
#
# in sky
#
# yellow and white
#
# old man
#
# tablecloth
#
# gold
#
# partly cloudy
#
# stool
#
# ponytail
#
# cat and dog
#
# video game
#
# tea
#
# y
#
# petting dog
#
# pictures
#
# ducks
#
# bike
#
# male
#
# eagle
#
# bat
#
# no one
#
# caucasian
#
# orange and white
#
# family
#
# pigtails
#
# off
#
# living room
#
# plants
#
# clear
#
# rabbit
#
# petting
#
# flat screen
#
# pants
#
# cake
#
# on ground
#
# climbing
#
# sandwiches
#
# cartoons
#
# sliding
#
# 6
#
# picnic blanket
#
# full
#
# goose
#
# wall
#
# having picnic
#
# hungry
#
# trees
#
# yarn
#
# wine glass
#
# nowhere
#
# baseballs
#
# ribs
#
# door handle
#
# on right
#
# fell
#
# birthday
#
# coat hanger
#
# bush
#
# middle
#
# bob
#
# apples
#
# on blanket
#
# exercising
#
# bed
#
# grilling
#
# picnic basket
#
# love
#
# ottoman
#
# teddy bears
#
# game console
#
# winter
#
# sandbox
#
# one on slide
#
# pugs
#
# bread
#
# in tree
#
# fish and duck
#
# chipmunk
#
# white and black
#
# one on right
#
# hawk
#
# books and plant
#
# toy
#
# on bench
#
# bushes
#
# coffee table
#
# white and orange
#
# reaching
#
# checkerboard
#
# checker
#
# red and yellow
#
# tan and white
#
# fishing pole
#
# holding hands
#
# playing football
#
# rose
#
# by door
#
# coat
#
# tea set
#
# summer
#
# robin
#
# cd
#
# bucket
#
# pail
#
# mantle
#
# drink
#
# marshmallow
#
# 16
#
# playing with cat
#
# small
#
# india
#
# front
#
# child
#
# in grill
#
# stuffed cat
#
# bear
#
# cats
#
# puppy
#
# toasting marshmallows
#
# plate of food
#
# potted plant
#
# in fireplace
#
# camera
#
# not sure
#
# above fireplace
#
# house
#
# in pond
#
# picnicking
#
# pet bed
#
# dog bed
#
# dessert
#
# shelf
#
# carpet
#
# very
#
# jumping rope
#
# fun
#
# 1 foot
#
# on couch
#
# video game system
#
# bee
#
# light brown
#
# on left
#
# birds
#
# leaves
#
# baseball bat
#
# neither
#
# bee stings
#
# can
#
# soda
#
# female
#
# football and baseball
#
# crescent
#
# begging
#
# standing up
#
# laughing
#
# ice cream
#
# holding them up
#
# raising them
#
# she dropped it
#
# short
#
# no idea
#
# owl
#
# 13
#
# party
#
# laying down
#
# on
#
# resting
#
# car
#
# surprise
#
# bbq
#
# none
#
# friends
#
# windows
#
# silver
#
# now
#
# on carpet
#
# go down slide
#
# na
#
# yoga
#
# stuffed animal
#
# no leaves
#
# crackle
#
# lonely
#
# maroon
#
# under tree
#
# catch
#
# in its bed
#
# in bed
#
# 14
#
# sofa
#
# lady
#
# jump
#
# jump on table
#
# playstation
#
# stuffed animals
#
# television
#
# green and yellow
#
# game system
#
# coats
#
# red and gray
#
# below
#
# plant and watermelon
#
# watermelon and plant
#
# in grass
#
# to eat
#
# both
#
# stripes
#
# boy on right
#
# banana split
#
# playing with dog
#
# in sandbox
#
# running away
#
# flying
#
# kitten
#
# 9
#
# pizza
#
# watching
#
# boy on slide
#
# disc
#
# shirt and pants
#
# dad
#
# blonde
#
# plant and basket
#
# to catch mouse
#
# burgers
#
# christmas tree
#
# looks like christmas tree
#
# standing on hind legs
#
# chiwawa
#
# corgi
#
# terrier
#
# mutt
#
# 100
#
# 20
#
# black white
#
# desert
#
# red white
#
# 15
#
# 11
#
# teeter totter
#
# movie
#
# hive
#
# toy car
#
# watching girl
#
# standing beside bicycle
#
# shock
#
# in park
#
# end table
#
# blue jay
#
# bird eggs
#
# pie and wine
#
# sticks
#
# on picnic blanket
#
# lots of windows
#
# slide down
#
# photo
#
# seagull
#
# bigger boy
#
# playing with it
#
# there are no leaves
#
# scenery
#
# person
#
# jokes
#
# area
#
# throw
#
# in middle
#
# pop
#
# crackling
#
# burning
#
# near log
#
# possibly
#
# orange and yellow
#
# cooking
#
# brown and white
#
# 12
#
# red wine
#
# grandpa
#
# adult
#
# net
#
# bookcase
#
# playing with baby
#
# potted plants
#
# jump roping
#
# having fun
#
# play
#
# checkers
#
# gingham
#
# happiness
#
# throwing football
#
# playing catch
#
# eat food
#
# grab food
#
# push it
#
# scratch it
#
# under window
#
# below window
#
# bird nest
#
# probably
#
# not clear
#
# room
#
# no dog
#
# cat bed
#
# dog and cat
#
# knee high
#
# medium
#
# very likely
#
# his left arm
#
# brown and green
#
# green and brown
#
# xbox
#
# game
#
# toy house
#
# center
#
# hands
#
# very hot
#
# for dog
#
# teapots
#
# drinking
#
# bottom left
#
# no guy
#
# get mouse
#
# fat
#
# chubby
#
# solid
#
# steak and corn
#
# not here
#
# another room
#
# kitchen
#
# there is none
#
# cupcakes
#
# asleep
#
# raked up
#
# blue and white
#
# running from it
#
# watching them
#
# looking at them
#
# balls
#
# bicycle
#
# guy
#
# disk
#
# soda can
#
# on chair
#
# looking at food
#
# sweat suit
#
# scooter handlebar
#
# in front
#
# campfire
#
# football baseball
#
# under fire
#
# large
#
# average
#
# quarter
#
# half
#
# khaki
#
# plant and picnic basket
#
# puppies
#
# no tv
#
# pets
#
# glass
#
# on tree
#
# gray shirt
#
# catch mouse
#
# he fell
#
# 65
#
# duck and fish
#
# nachos
#
# shoes
#
# in front of bush
#
# her stuffed animal
#
# mantel
#
# on seesaw
#
# on see saw
#
# cubes
#
# plant pot
#
# her pants
#
# christmas
#
# tree can be used for christmas
#
# christmas tree shape
#
# it looks like christmas tree
#
# clump of shrubs with stems
#
# shrub
#
# like small tree
#
# small trees
#
# small tree
#
# shrub with branches of moderate length
#
# one is
#
# leaping towards woman
#
# gi
#
# standing on two legs
#
# waiting for somebody
#
# looking at door
#
# scratching her thigh
#
# no chair
#
# mess
#
# because he is old
#
# lost his job
#
# his food is gone
#
# no food
#
# no where to sit
#
# chair is gone
#
# junk
#
# lap dog
#
# shiatsu
#
# peekaboo
#
# 30
#
# white black
#
# es
#
# waffle
#
# in photo
#
# everywhere
#
# all around
#
# picture on right
#
# green one
#
# flexing them
#
# cheering
#
# talking
#
# white and red
#
# away from woman
#
# east
#
# they dropped it
#
# it was put there
#
# girl dancing
#
# girl dropped it
#
# no steps
#
# because he is short
#
# too short
#
# monkey bars are high
#
# he is too short
#
# 78
#
# climbing up
#
# going up
#
# promotion
#
# her birthday
#
# picnic foods
#
# snacks
#
# sandwich
#
# laying
#
# on her back
#
# prone
#
# lying down
#
# lying position
#
# flat
#
# rust
#
# petting cat
#
# playing with kitten
#
# about to hug her cat
#
# girl falling
#
# pillowcases
#
# no orange thing in tree
#
# plant and books
#
# books
#
# blue green yellow
#
# green yellow and blue
#
# just sitting
#
# just sitting there
#
# hat rack
#
# coat stand
#
# relax
#
# wave
#
# train
#
# light blue
#
# sliding down
#
# riding slide
#
# going down slide
#
# biking
#
# pushing bike
#
# standing next to bike
#
# holding her bike up
#
# holding bike
#
# color
#
# no sand under it
#
# it is curved
#
# it is purple and red
#
# weeds
#
# daisy
#
# pansies
#
# yes and swimming
#
# fire in fireplace
#
# his right
#
# he is from india
#
# with
#
# family member
#
# sister
#
# homeowner
#
# dismay
#
# fear
#
# scared
#
# worrisome
#
# in foreground
#
# right in front
#
# running to right
#
# bottom
#
# running on grass
#
# there are 3 mushroom by log
#
# next to woman
#
# near sidewalk
#
# between boy and woman
#
# at park
#
# by sidewalk
#
# next to sidewalk
#
# next to bench
#
# looking for food
#
# pecking grass
#
# her baby
#
# god
#
# nobody
#
# in pit
#
# plush cat
#
# stuffed kitten
#
# plate and glass
#
# plate pie knife glass
#
# pie and drink
#
# glass of wine and plate of pie
#
# food cups
#
# food and drink
#
# wine pie
#
# man and woman
#
# girl and man
#
# page boy
#
# paige boy
#
# straight
#
# bob cut
#
# pug
#
# gold and white
#
# dachshund
#
# appears to be
#
# sun and 1 cloud
#
# roasters
#
# marshmallow on stick
#
# marshmallow roasting sticks
#
# skewers
#
# marshmallows on sticks
#
# toast marshmallows
#
# on tablecloth
#
# my best guess is no
#
# unknown
#
# tv and game system
#
# tv and video game console
#
# tv and video game
#
# tv and game console
#
# matches
#
# he likes it
#
# favorite color
#
# his style
#
# it matches
#
# matching
#
# to stand out
#
# to be seen
#
# day
#
# sunlight
#
# 1 hour ago
#
# while ago
#
# afternoon
#
# recently
#
# morning
#
# during day
#
# picture frame
#
# green and yellow framed picture
#
# near cat
#
# loor
#
# meal
#
# plate with food
#
# braids
#
# ponytails
#
# red and purple
#
# tv is off
#
# photograph
#
# small dog
#
# exercise
#
# red skateboard
#
# stuffed toy
#
# young lady
#
# old brother
#
# older boy
#
# no leafs
#
# there are none
#
# nature
#
# between
#
# photographer
#
# owner
#
# me
#
# viewer
#
# over fireplace
#
# right of tree
#
# top
#
# r
#
# boardwalk
#
# little boy being held
#
# weather
#
# life
#
# red one
#
# persian
#
# woven
#
# sitting on blanket
#
# sitting down
#
# middle of picture
#
# between tree and girl
#
# behind woman
#
# in gordon
#
# pointing
#
# light purple gray
#
# reddish brown
#
# tablet
#
# pad
#
# her leg
#
# paper
#
# notebook
#
# it is yellow dog
#
# cracking
#
# no sound
#
# no friends
#
# alone
#
# no allowance
#
# he was robbed
#
# women
#
# grandma
#
# mushroom and sun
#
# children
#
# unsure
#
# in front of tree
#
# beneath tree
#
# under tree on right
#
# asking for baby
#
# reaching for baby
#
# holding baby
#
# trying to take baby
#
# wood and wrought iron
#
# wood and metal
#
# kid
#
# tree log
#
# bird and nest
#
# bugs bunny
#
# kids show
#
# kid friendly show
#
# news
#
# gold blue
#
# orange and blue
#
# blue and yellow
#
# maroon and brown
#
# mostly red
#
# in dog bed
#
# red and orange
#
# bat on ground
#
# ball and bat on grass
#
# baseball bat nearby
#
# there is ball and bat in grass
#
# bat and baseball on ground
#
# its on ground
#
# bat and ball
#
# ball and bat
#
# baseball bat on ground
#
# ball bat
#
# thongs
#
# tongues
#
# barbecuing
#
# holding tongs
#
# green and white
#
# sitting next to fire
#
# pie and chicken
#
# pie and meatballs and spaghetti
#
# pie and turkey
#
# pot pie
#
# no man here
#
# there is no young man
#
# watching bird
#
# tortoise
#
# loveseat
#
# near window
#
# fishing rod
#
# dog is running toward man
#
# they are yellow
#
# on bookcase
#
# on bookshelf
#
# on shelf
#
# top shelf
#
# cloth
#
# to play with baby
#
# he is playing with child
#
# playing with child
#
# so he can be beside child
#
# piece of meat
#
# under table
#
# jumping into chair
#
# on rug and chair
#
# easy
#
# it is easy
#
# sunflowers
#
# blue teddy bear
#
# toy and cat
#
# cat on couch
#
# gir
#
# skipping rope
#
# rope jumping
#
# not odd
#
# possible
#
# he had fun sliding down
#
# cat is playing with yarn
#
# cat is playing with it
#
# cat toys
#
# to play with
#
# for play
#
# not yet
#
# there is no squirrel
#
# nuts
#
# futbol
#
# block
#
# barbecue tongs
#
# on date
#
# romantic
#
# pick nick
#
# joyful
#
# air
#
# tired
#
# jump up
#
# leap on it
#
# get food
#
# jump on it
#
# jump onto table
#
# scratch
#
# in front of window
#
# beside stool
#
# in floor in front of window
#
# mirror
#
# color of frisbee is blue
#
# fruit
#
# getting ready to grab it
#
# feeding squirrel
#
# putting food on it
#
# eating picnic food
#
# picnic blanket and food
#
# blanket and food
#
# bunny lives in park
#
# there is food
#
# for food
#
# lives nearby
#
# hungary
#
# overcast
#
# sunny and overcast
#
# partly sunny
#
# on sidewalk
#
# in living room
#
# behind women
#
# pop cut
#
# cement
#
# trees and shrubs
#
# trees and bushes
#
# navy
#
# he may choke
#
# it would be gone
#
# he dies
#
# tummy ache
#
# there is no dog
#
# teeth clean
#
# he gets full
#
# no dog in pic
#
# 2 ft
#
# not very high
#
# 2 feet
#
# low
#
# not very
#
# somewhat
#
# somewhat likely
#
# likely
#
# not likely
#
# 100 percent
#
# slightly
#
# his left
#
# animals bed
#
# pet
#
# checks
#
# colored
#
# owner liked color
#
# manufacture chose that color
#
# painted
#
# owners chose it
#
# color of material
#
# like red
#
# it was made that way
#
# fabric
#
# jungle gym
#
# wall base
#
# next to door
#
# nintendo
#
# wii
#
# tekken
#
# ball of yarn
#
# string
#
# girl might fall off of stool
#
# may fall
#
# she could fall
#
# falling off stool
#
# she might fall
#
# shooing away rat
#
# chasing it
#
# babysitting
#
# purple and blue
#
# melon
#
# on soda
#
# getting too hot
#
# sitting at impossible angle
#
# for watching
#
# placed there
#
# placed there so man could watch it
#
# video console
#
# electronic gaming system
#
# video games
#
# gaming system
#
# controller
#
# doll house
#
# between logs
#
# on logs
#
# between two people
#
# in between two people
#
# og
#
# in his hand
#
# in left guys hands
#
# boy in blue hands
#
# coats and hats
#
# jacket
#
# extreme hot
#
# burning hot
#
# hot
#
# warm
#
# red gray
#
# under
#
# under to right
#
# under right pane
#
# below it
#
# pick up dog
#
# reach for his dog
#
# pick dog up
#
# for cat
#
# picking up dog
#
# greet dog
#
# in front of girl
#
# toward front
#
# it is in foreground
#
# teacups
#
# teapot set
#
# he is happy
#
# funny thought
#
# watching something funny
#
# because he is happy
#
# remembering
#
# he is crazy
#
# thinking of joke
#
# holding can
#
# holding can of soda
#
# thinking
#
# turned on
#
# sitting there
#
# its sitting there
#
# in room
#
# walking away from men
#
# pane
#
# champagne
#
# there are no guys in picture
#
# gaming
#
# fax
#
# ps3
#
# trying to get mouse
#
# chasing mouse
#
# bunny
#
# s
#
# yard
#
# cloudy day
#
# reflection
#
# season
#
# it will be night
#
# science
#
# strange day
#
# watermelon flowers
#
# watermelon plant
#
# pear
#
# chunky
#
# obese
#
# heavy set
#
# bottom left corner
#
# far left
#
# lower left
#
# hunting
#
# hunger
#
# eat it
#
# t
#
# striped
#
# flat color
#
# no pattern
#
# fish and frog
#
# other boy
#
# in storage
#
# in kitchen
#
# stuffed animal and blocks
#
# hornet nest
#
# sleep
#
# young girl
#
# door and picture
#
# front middle
#
# to left of man
#
# blown away
#
# spring season
#
# it is getting cold outside
#
# they fell off
#
# because they flew away
#
# they were cleaned up already
#
# raked
#
# petting animal
#
# with man
#
# held by man
#
# in hands
#
# arms of man
#
# toward grandpa on right
#
# towards front
#
# on top of carpet
#
# softball
#
# base
#
# girl is
#
# woman is
#
# running from
#
# right hand
#
# hand
#
# bird and cloud
#
# looking at
#
# beehive and bird
#
# sparrow
#
# cardinal
#
# color of chairs are blue
#
# curtains
#
# desk
#
# on coffee table
#
# table top
#
# 3 paintings
#
# rocking
#
# falling
#
# because boy put it there
#
# for boy to ride
#
# kids put them there
#
# not being used
#
# kids left it
#
# boy left it there
#
# because boy was playing with it
#
# to play on
#
# land and air
#
# around pond
#
# pond and air
#
# lake
#
# shovel
#
# yellow and gray
#
# white and brown
#
# two colors are yellow and white
#
# brown and gray
#
# bbq pit
#
# right and left
#
# both sides of couch
#
# by couch
#
# next to couch
#
# each side of sofa
#
# left and right of couch
#
# beside loveseat
#
# on either side of sofa
#
# each end of couch
#
# shadow
#
# lot
#
# tv show
#
# television show
#
# her cat
#
# something showed up in tv
#
# blue bird
#
# honey
#
# lot of bee stings
#
# getting stung by bees
#
# stung
#
# stung by bees
#
# getting stung
#
# toy bear
#
# because she can
#
# balance
#
# upset
#
# sliding board boy
#
# bucket and shovel
#
# o
#
# mug
#
# blue can
#
# black and orange
#
# begging for food
#
# black shirt and black pants
#
# shirt and jeans
#
# jumpsuit
#
# black clothes
#
# all black
#
# left corner of picture
#
# scooter handle
#
# handlebar of scooter
#
# right side
#
# ews
#
# girl in white
#
# girl in white top
#
# grandfather
#
# hot dogs
#
# looking at butterfly
#
# she standing
#
# giving him medicine
#
# in front of log
#
# in front of couple
#
# by people
#
# no sharing
#
# man on right
#
# guy on right
#
# in fire
#
# not there
#
# between people
#
# near girl
#
# watermelon and wine
#
# very big
#
# big
#
# medium size
#
# checked
#
# new moon
#
# waning crescent
#
# picnic basket and plant
#
# basket and plant
#
# puggle
#
# of girl
#
# no tv is in room
#
# gone
#
# not in picture
#
# to right of slide
#
# in background
#
# background
#
# beside slide
#
# by slide
#
# in air
#
# dog and kitten
#
# animals
#
# canon table
#
# sunrise
#
# there are bees
#
# scared of bees
#
# eggs
#
# barney
#
# kids movie
#
# blank screen
#
# sleeping in cat bed
#
# on its bed
#
# gray shirt and black pants
#
# pants and top
#
# blue shirt and black pants
#
# black and gray
#
# alcohol
#
# left sky
#
# upper left corner
#
# cherry pie
#
# to land
#
# on top of rug
#
# by coat rack
#
# window on right
#
# right one
#
# has fallen
#
# he sat down
#
# he fall
#
# throw rug
#
# 60
#
# 50
#
# very old
#
# seventy
#
# 67
#
# doorknob
#
# door knob
#
# dance
#
# logs
#
# woods
#
# young boy
#
# light beige
#
# pot plant
#
# in park on grass
#
# koi and mallard
#
# rug on floor
#
# owl in tree
#
# owk
#
# she likes watermelon
#
# chips
#
# platter of food
#
# popcorn
#
# snack
#
# footrest
#
# hassock
#
# small stool
#
# man is holding tongs
#
# in front of guy
#
# next to boy
#
# beside man
#
# next to bush
#
# by man
#
# underneath windows
#
# next to table
#
# her father
#
# boy in red
#
# chicken
#
# hamburgers
#
# swinging
#
# on monkey bars
#
# playing on jungle bars
#
# playing on monkey bars
#
# hanging
#
# lcd
#
# sony
#
# red checkered
#
# checker red white
#
# on grass running towards girl
#
# next to blanket
#
# running to girl
#
# between sidewalk
#
# corner of sidewalk
#
# corner
#
# between skater and woman
#
# in corner of sidewalks
#
# next to man
#
# burgundy
#
# boys
#
# her toy
#
# school
#
# 5 mice
#
# blue and gray
#
# playground
#
# white and pink
#
# white and purple
#
# white gray
#
# white and gray
#
# filling sand
#
#
#
# light blue
#
# she finished her chores
#
# shock
#
# 13
#
# hot
#
# he is trying to catch frisbee
#
# girl running
#
# he is happy
#
# throwing football
#
# it got ripped out
#
# playing blocks
#
# seeing flower
#
# each end of couch
#
# comedy
#
# their engagement
#
# walking with dog
#
# on dinner table
#
# daisy
#
# 7
#
# video console
#
# poodle
#
# heating
#
# koi
#
# black and orange
#
# girl and old man
#
# white and orange
#
# walking around instead
#
# wine glass
#
# watching something funny
#
# none
#
# shirt and jeans
#
# red and purple
#
# for it to sleep
#
# northeast
#
# lonely
#
# area
#
# with man
#
# she standing
#
# babysitter
#
# jacket
#
# baseball bat
#
# blonde
#
# reading
#
# seesaw and sandbox
#
# her dog
#
# it will fall over
#
# armrest
#
# unlovable
#
# blue stuffed animal
#
# up
#
# soup
#
# terrier
#
# standing beside bicycle
#
# away
#
# on tablecloth
#
# green yellow and blue
#
# books
#
# it became logs
#
# he is bending down
#
# women
#
# dog and boy on table
#
# champagne
#
# between 2 trees
#
# messing with plant
#
# kids
#
# under right pane
#
# mom
#
# puppies
#
# moon
#
# left corner
#
# lives nearby
#
# sunset
#
# what is in tree
#
# both
#
# transportation
#
# picnic blanket and food
#
# his style
#
# near center of picture
#
# their kids
#
# circular
#
# children
#
# background
#
# between slide and tree
#
# chihuahua
#
# owl in tree
#
# game console
#
# to pick dog
#
# yarn ball
#
# pillowcases
#
# 32 each
#
# cut down
#
# pop cut
#
# on arm of couch
#
# books and plant
#
# next to tree
#
# on chair
#
# play with dog
#
# hanging
#
# to feed duck
#
# tray
#
# right side of sky
#
# playing with dog
#
# 2 bottles of wine
#
# next to sidewalk
#
# no style
#
# to play with
#
# watermelon plant
#
# food and drinks
#
# marshmallows on sticks
#
# spaghetti with meatballs
#
# land and air
#
# holding bone for dog
#
# bees
#
# feet
#
# lillys
#
# holding arm up
#
# red one
#
# warmth
#
# shoes
#
# game system
#
# arm of chair
#
# near window
#
# paper
#
# close to each other
#
# blue teddy bear
#
# plates
#
# happiness
#
# coats
#
# she dropped it
#
# kids show
#
# he wants chair and boy is in way
#
# holding bike
#
# tv is funny
#
# because she rode bike
#
# swinging
#
# beside fireplace
#
# on right side
#
# higher
#
# on its bed
#
# walking
#
# on back of chair
#
# right of children
#
# one on carpet and one next to carpet
#
# 5
#
# man on right
#
# while ago
#
# not likely
#
# watermelon and wine
#
# poly with dog
#
# bushes
#
# setting table
#
# 200
#
# on left of picture
#
# cake
#
# log
#
# leaping
#
# day off
#
# fowl
#
# pictures
#
# blue green yellow
#
# around pond
#
# sunglasses
#
# tie back
#
# under couple
#
# sunny
#
# scratch it
#
# white and brown
#
# beige
#
# grandchild
#
# 18
#
# steak and hot dog
#
# plate pie knife glass
#
# it would be gone
#
# red skateboard
#
# partly sunny
#
# cloth
#
# climbing monkey bars
#
# checks
#
# ews
#
# to play
#
# one higher
#
# it is curved
#
# classy
#
# nobody
#
# kid
#
# flying and in tree
#
# hand
#
# almost all
#
# checker
#
# honey
#
# cement
#
# book
#
# bulldog
#
# remembering
#
# person taking picture
#
# in front of couch
#
# toward front
#
# to be seen
#
# in its bed
#
# worrisome
#
# doll house and blocks
#
# her pants
#
# standing on two legs
#
# in grill
#
# saying stop
#
# wicker picnic
#
# my best guess is no
#
# dog is misbehaving
#
# for sliding
#
# wanting attention
#
# afraid
#
# mad at boy
#
# door handle
#
# boy and girl
#
# tekken
#
# biking
#
# bottle of wine
#
# brown
#
# gold orange red
#
# blue and white
#
# not sure
#
# color
#
# older boy
#
# t
#
# puppy
#
# color of frisbee is blue
#
# with lady
#
# sunflowers
#
# running away
#
# to get cheese
#
# to eat
#
# piece of meat
#
# love you
#
# toward grandpa on right
#
# sitting sideways
#
# picking apples
#
# boy on right
#
# broken
#
# they are playing football
#
# to use in sandbox
#
# on woman
#
# tree can be used for christmas
#
# light pink
#
# turtles
#
# movie
#
# on ground behind man
#
# lot to cook
#
# playing around
#
# pink flowers
#
# leafy plant
#
# they are yellow
#
# book glass
#
# gray or black
#
# pie and wine
#
# its on ground
#
# daylight
#
# 2 plants on either side of window
#
# watching tv
#
# baby robins
#
# sunrise
#
# waiting for company
#
# putting nest back in tree
#
# short person hung it
#
# forks
#
# seventy
#
# on ottoman
#
# dog eating corn
#
# woman is
#
# because boy put it there
#
# girl in white
#
# in fire pit
#
# unknown
#
# underneath window
#
# dog
#
# black and white
#
# to play with yarn
#
# tortoise
#
# will go down
#
# left corner of picture
#
# sitting down
#
# under to right
#
# red orange yellow
#
# kneeling down
#
# drying off
#
# sitting on chair with cat
#
# she has hot dog
#
# hide and seek
#
# girls hand
#
# next to lady
#
# below
#
# sitting together in park
#
# juice
#
# 60
#
# frisbee
#
# it looks curly
#
# skipping rope
#
# coffee table
#
# guy
#
# on coffee table
#
# on see saw
#
# double doors
#
# from riding
#
# teetering
#
# orange red
#
# on soda
#
# ...
#
# she could fall
#
# 4
#
# her toy
#
# 1
#
# eating picnic food
#
# sun out
#
# game
#
# because it wants to
#
# friday night
#
# having picnic
#
# garden
#
# so he can be beside child
#
# on horizon
#
# winning lottery
#
# dog park
#
# standing on hind legs with front paws on table
#
# herself
#
# water
#
# next to blanket
#
# white
#
# baby
#
# playing with sand
#
# goldfish
#
# legs
#
# male
#
# flower
#
# against tree
#
# boy on left
#
# ground
#
# s
#
# dog is looking at puppies
#
# flying back to hive
#
# teacups
#
# no guy
#
# jump roping
#
# bouncing
#
# lap dog
#
# pot with plant
#
# 2 years old
#
# on top of fireplace
#
# light beige
#
# fire
#
# laying down sleeping
#
# it is excited
#
# sitting up straight
#
# sleeping cat
#
# check
#
# by wall
#
# windowsill
#
# it belongs to man
#
# plaid
#
# giving her marshmallow
#
# funny thought
#
# on rug
#
# mountain ridge
#
# having fun with his cat
#
# controller
#
# bottom left
#
# watching girl
#
# nowhere
#
# on picnic spread
#
# he is crazy
#
# forward
#
# fir
#
# squirrel
#
# next to fireplace
#
# right one
#
# all around
#
# teal
#
# reach bird nest
#
# going up
#
# sliding board boy
#
# pillow
#
# dining room
#
# koy
#
# slide down
#
# warm
#
# on wall
#
# help
#
# gir
#
# there is none
#
# it is easy
#
# animal is duck
#
# it will be night
#
# having pie
#
# notepad
#
# chunky
#
# beside left tree
#
# girl falling
#
# loor
#
# sleeping on side
#
# cartoons
#
# both sides of couch
#
# plates and silverware
#
# house plants
#
# picnic basket and food
#
# pet
#
# indoor plant
#
# funny show
#
# at pond
#
# kneeling
#
# below window
#
# summer
#
# birds
#
# near picture
#
# on their bikes
#
# oval
#
# mosquito
#
# get ball
#
# checkers
#
# soccer baseball skateboarding
#
# eat food
#
# large
#
# reaching for dad
#
# tv remote
#
# in his bed
#
# dog on right
#
# playing game
#
# playhouse
#
# go down
#
# mostly
#
# because boy is jumping
#
# matching
#
# red and gray
#
# between skater and woman
#
# tilapia
#
# chips and dip
#
# owner
#
# other boy
#
# lasagna
#
# drinking
#
# jumping towards woman
#
# chocolate
#
# because boy was playing with it
#
# tv is off
#
# jump on it
#
# playstation
#
# in room
#
# to go down
#
# someone sold it
#
# holding it
#
# in pit
#
# lost his job
#
# teeth clean
#
# soffa
#
# bat on ground
#
# on either side of sofa
#
# on armchair
#
# kids put them there
#
# looking at butterfly
#
# red and orange
#
# slide and monkey bars
#
# elderly
#
# getting stung
#
# saluting
#
# left of couch
#
# lunch
#
# drinks
#
# apples
#
# quarter
#
# joyful
#
# pants and top
#
# potted plant
#
# by window
#
# that is butterfly
#
# tablecloth
#
# being afraid of mice
#
# no dog in pic
#
# green apple
#
# roasting them
#
# inside frame
#
# indoors
#
# exercising
#
# food and drink
#
# in left guys hands
#
# no one else is home
#
# double
#
# green plant
#
# another room
#
# dog has slipper
#
# man
#
# middle age
#
# talking to someone
#
# bird and nest
#
# ducks
#
# concert
#
# table
#
# flying under tree
#
# gym equipment
#
# eating pizza
#
# bad architecture
#
# middle
#
# it was white bone dog likes bones
#
# there is bug on ground
#
# wine
#
# goose
#
# ponytails
#
# trees and shrubs
#
# sad
#
# putting back
#
# scooter handle
#
# pugs
#
# hug
#
# colored
#
# chipmunk
#
# balancing
#
# smiling
#
# above sofa
#
# lots
#
# underneath windows
#
# walking towards him
#
# playing on jungle bars
#
# bottle
#
# leap on it
#
# waving
#
# he may choke
#
# argument
#
# wool
#
# next to table
#
# standing on blanket
#
# on edge of sandbox
#
# behind women
#
# jogging
#
# beside pond
#
# on back wall
#
# middle of floor
#
# football baseball
#
# photograph
#
# front right
#
# getting stung by bees
#
# ps3
#
# owl
#
# getting ready to grab it
#
# lower left
#
# sofa
#
# funny tv show
#
# stuff
#
# boy in black
#
# small tree
#
# terrified
#
# sunny with cloud
#
# on right of couch
#
# 5000c
#
# kickball
#
# grilling
#
# barbie doll
#
# near cat
#
# red and white checkered
#
# dollhouse and robot
#
# cat toy
#
# taking it
#
# next to stool
#
# animals
#
# on top baby
#
# 2
#
# horse
#
# sony
#
# end table
#
# on seesaw
#
# potted bush
#
# between two
#
# going down slide
#
# to right
#
# sunny with some clouds
#
# under fire
#
# underneath table
#
# rope
#
# to get dog
#
# to catch it
#
# cherry pie
#
# kitten
#
# footstool
#
# opening them
#
# flowers
#
# on coach
#
# by chair
#
# waving them
#
# filling it with sand
#
# so cat can be seen
#
# yarn
#
# viewing
#
# 3 paintings
#
# hat rack
#
# father is playing with him
#
# upper
#
# paige boy
#
# leaning on stand
#
# between desk and sofa
#
# chipmunks
#
# plushie
#
# he wants to be picked up
#
# tea party
#
# kids movie
#
# by lady
#
# in cat bed
#
# at
#
# christmas
#
# watching television
#
# woman in red shirt
#
# low
#
# dog has shoe
#
# black white
#
# tail vertical
#
# barney
#
# corn
#
# eat cheese
#
# plenty for everyone
#
# under tree
#
# raccoon
#
# sleep in
#
# grape
#
# one for each meat
#
# by yarn ball
#
# on baby
#
# admiring flowers
#
# snack
#
# brunette
#
# cardinal
#
# mud
#
# bending
#
# floor under paintings
#
# crackle
#
# pants or sidewalk
#
# noon
#
# dance
#
# doorknob
#
# picking it up
#
# no pattern
#
# clump of shrubs with stems
#
# beside man
#
# on left
#
# petting cat
#
# paintings
#
# eating pie
#
# probably
#
# have picnic
#
# pie and chicken
#
# stuffed animal
#
# they love grilling
#
# duck and fishes
#
# r
#
# pick nick
#
# girl and boy
#
# meal
#
# to see nest
#
# putting book on shelf
#
# jumping into chair
#
# beside girl
#
# painted
#
# between boy and woman
#
# taking it out
#
# next to boy
#
# it blew away
#
# weather
#
# on pavement
#
# partly
#
# other room
#
# use
#
# talking
#
# bookcase
#
# playing with baby
#
# hives
#
# for football
#
# right tree
#
# walking on it
#
# red wine
#
# long sleeves
#
# 40
#
# 2 ft
#
# football
#
# plants and fish
#
# pyramids
#
# og
#
# marshmallow
#
# dog and cat
#
# there are 2 people
#
# on top of rug
#
# most people would say kickstand
#
# logs
#
# next to woman
#
# underpainting
#
# not here
#
# pop
#
# climbing
#
# flowered
#
# they will be burned
#
# something showed up in tv
#
# stand
#
# plain
#
# east
#
# 1 for each of people sitting
#
# computer
#
# cheese
#
# it will drop
#
# sparrow
#
# cold
#
# stung
#
# scared of bees
#
# sun
#
# bugs bunny
#
# couch handle
#
# plant and watermelon
#
# in between both
#
# walkway
#
# doll and tea set
#
# balancing on it
#
# she is not sleeping
#
# blonde one
#
# sees ball
#
# feeding squirrel
#
# on grass running towards girl
#
# many
#
# curtains
#
# life
#
# parents
#
# what is dog doing
#
# roses
#
# brown with white spots
#
# replaced with button
#
# no orange thing in tree
#
# in table
#
# 3 birds
#
# burn
#
# boys
#
# jumping up
#
# toward pond
#
# sunny and overcast
#
# middle of room
#
# blue
#
# lost
#
# coat
#
# logs and fire
#
# strange day
#
# mo
#
# desert
#
# turkey
#
# arm of couch
#
# next to door
#
# wasps
#
# right in front
#
# not there
#
# towards man
#
# visa
#
# chair is gone
#
# see saw
#
# carpet
#
# owner put it there
#
# flowery
#
# stuffed animal and blocks
#
# burger
#
# fall over
#
# attention
#
# someone was sitting in chair
#
# very
#
# sunset photo
#
# pushing bike
#
# she sits
#
# toy car
#
# cd disk
#
# grill lid
#
# 55
#
# yellow and gold
#
# on sandbox
#
# boy and dog on table
#
# pet bed
#
# skateboarding baseball soccer
#
# wants to play with it
#
# jungle gym
#
# napkins
#
# cheering
#
# burning
#
# head and left arm
#
# mushroom and sun
#
# too short
#
# invisible steps
#
# cotton
#
# he was robbed
#
# golden
#
# jumping on couch
#
# green one
#
# bird eggs
#
# left sky
#
# riding slide
#
# ice cream
#
# sitting on arm of couch
#
# boy on slide
#
# barbecue
#
# plant pot
#
# on bookshelf
#
# sitting on log
#
# burgers
#
# picnic basket
#
# 65
#
# fish and lilies
#
# between
#
# trees
#
# yes it is
#
# playing with child
#
# morning
#
# gone
#
# 44
#
# toys books cd
#
# like small tree
#
# behind monkey bar
#
# pine tree
#
# old lady
#
# coat stand
#
# white and black
#
# checker red white
#
# spring season
#
# red shirt
#
# gold and white
#
# sweater and pants
#
# sky
#
# 3 years
#
# balance
#
# birthday
#
# on plates
#
# nose
#
# middle of logs
#
# to slide
#
# brown and black
#
# boy in blue hands
#
# log to right
#
# noble fir
#
# looks like christmas tree
#
# night
#
# in other room
#
# 6
#
# performing trick
#
# likely
#
# after
#
# monkey bars are high
#
# browns
#
# begging for food
#
# mid right
#
# very right
#
# next to bushes
#
# television
#
# right hand
#
# near wall
#
# relaxing
#
# caucasian
#
# petting animal
#
# grab
#
# each side of sofa
#
# in gordon
#
# young
#
# sitting on couch
#
# rabbit
#
# near blanket
#
# standing on it
#
# hive
#
# people were sitting there
#
# in center
#
# on kid
#
# baby and cat
#
# to left
#
# shish kabob
#
# blue and gray
#
# it was made that way
#
# purple and blue
#
# monkey b
#
# everyone else left
#
# watching fish in pond
#
# 14
#
# it is getting cold outside
#
# warming up
#
# park right side
#
# stretching
#
# brown seat
#
# alone
#
# in middle
#
# in air
#
# young lady
#
# breakdance
#
# to land
#
# it appears to be pie
#
# round
#
# toast marshmallows
#
# den
#
# pizza and salad
#
# campfire
#
# in shelf
#
# in house
#
# sausages
#
# 45
#
# most of it
#
# these are cats not dogs
#
# rectangular
#
# clear and sunny
#
# playing
#
# sleepy
#
# on scooter
#
# bee stings
#
# older woman
#
# waving hand
#
# near pond
#
# warming his hands over fire
#
# in corner
#
# she likes watermelon
#
# toy robot
#
# pot pie
#
# skewers
#
# white guy with black hair
#
# serving tea
#
# platter of food
#
# feed duck
#
# dog jumping off couch
#
# house blocks
#
# red hardback
#
# pond
#
# toys and camera
#
# getting warm
#
# stool
#
# bottles
#
# 50
#
# rode bicycle
#
# in dog bed
#
# jumping
#
# plant and picnic basket
#
# trees and bushes
#
# to keep warm
#
# weeds
#
# begging
#
# right girl
#
# likes to
#
# walking on sidewalk
#
# white and gray
#
# khaki
#
# on her neck
#
# frame
#
# center
#
# pedal
#
# bees heading toward dog
#
# long pants
#
# smores
#
# no dog
#
# in between
#
# tree is full grown
#
# cracking
#
# maybe
#
# now
#
# placed there so man could watch it
#
# na
#
# trying to get on couch
#
# cooking on each
#
# tossing it
#
# bullying
#
# left there
#
# in sky and tree
#
# playing with girl
#
# eating on sofa
#
# he is too short
#
# pie and drink
#
# she likes it
#
# she might fall
#
# toy bear
#
# mantle
#
# side by side
#
# seesaw
#
# like red
#
# fern
#
# living room
#
# walking dog
#
# considering to eat it
#
# white black
#
# lego bricks
#
# ball of yarn
#
# thinking of joke
#
# nothing
#
# feeding birds
#
# under
#
# woman on right
#
# possible
#
# waiting to be drunk
#
# step
#
# fear
#
# holding out
#
# laughing
#
# pretending
#
# black clothes
#
# reaching for wine bottle
#
# top of picture
#
# not yet
#
# sitting on blue chair
#
# cat and baby
#
# getting too hot
#
# toddler
#
# it matches
#
# basket hamburger wine
#
# football and birds and butterflies
#
# hamburgers
#
# kids left it
#
# mess
#
# dandelion
#
# sunlight
#
# sleeping in cat bed
#
# pizza salad
#
# fish
#
# holding can of soda
#
# to left of man
#
# to drink
#
# reach for his dog
#
# frogs
#
# shelf
#
# to have fun
#
# because they flew away
#
# dog has something
#
# ball and bat
#
# get mouse
#
# cat is playing with it
#
# burger and hot dog
#
# nightshade
#
# my best guess is none
#
# cat dog
#
# ladies feet
#
# blanket
#
# chips
#
# jungle jim
#
# out
#
# tan and white
#
# special design
#
# 78
#
# man standing at grill
#
# 79
#
# crescent
#
# standing on 1 leg
#
# picnic foods
#
# neither
#
# notebook
#
# bees hive
#
# no man here
#
# empty
#
# floral pattern
#
# cats
#
# checkered
#
# above woman
#
# by man
#
# fax
#
# ginger
#
# raked
#
# eat it
#
# fall down
#
# having meal
#
# in foreground
#
# lower right
#
# balanced
#
# to get yarn
#
# pie wine and watermelon
#
# picnic
#
# redhead
#
# there is food
#
# to exit on to grass
#
# behind man
#
# mutt
#
# he is from india
#
# falcon
#
# on loveseat
#
# pants
#
# 85
#
# to sleep in
#
# 4q
#
# brown cat
#
# television is amusing
#
# in front of girl
#
# next to couch
#
# not very
#
# butterflies
#
# violet
#
# in sky
#
# hands
#
# in storage
#
# sleep
#
# boy in red
#
# sandbox
#
# peanut butter toast
#
# sandwich
#
# he drove it there
#
# roasting
#
# different food
#
# bed
#
# scratching tree and sitting on log
#
# short
#
# sandbox and monkey bars
#
# soccer
#
# sliding onto picnic blanket
#
# picking up dog
#
# kicking
#
# woman sold it
#
# cloud
#
# navy
#
# welcome mat
#
# tired
#
# there is no squirrel
#
# pumpkin
#
# to reach nest
#
# pizza on table
#
# blankets
#
# girl and man
#
# on wall to right of window
#
# sweat suit
#
# appears to be
#
# gold blue
#
# attacking raccoon
#
# seesawing
#
# page boy
#
# holding
#
# in center of picture
#
# in bed
#
# for picnic
#
# jump rope
#
# it is in foreground
#
# reaching for baby
#
# came out
#
# giggling
#
# playing soccer
#
# kitten to play
#
# between people
#
# carrying tray
#
# chubby
#
# small trees
#
# sticks
#
# jump on table
#
# bone
#
# 80
#
# reach nest
#
# pine
#
# on rack
#
# wine bottles
#
# ribs
#
# he had fun sliding down
#
# in park on grass
#
# nuts
#
# shiatsu
#
# on table
#
# soda
#
# kid and bucket
#
# they are friendly
#
# bad
#
# day
#
# junk
#
# fringes
#
# next to bush
#
# on picnic blanket
#
# to sleep
#
# ducks and bluebird
#
# one on right
#
# running on grass
#
# there are none
#
# baseball bat nearby
#
# on floor
#
# playing football
#
# sweater
#
# sunset behind rolling hills
#
# stung by bees
#
# playing with dad
#
# piece of corn
#
# spreading
#
# one higher than other
#
# pane
#
# weed
#
# watching bunny
#
# push it
#
# grandpa
#
# between hat stand and potted plant
#
# wood and wrought iron
#
# stripes
#
# b c d
#
# cooking
#
# rode bike
#
# throw
#
# beneath tree
#
# dismay
#
# mice
#
# bird nest
#
# doll house
#
# meeting woman
#
# path
#
# daytime
#
# senior
#
# water lilies
#
# between tree and girl
#
# pie and meatballs and spaghetti
#
# coat rack
#
# everyone
#
# straight
#
# soccer baseball and skateboard
#
# dog bed
#
# striking pose
#
# to feed ducks
#
# preventing baby from eating sand
#
# train
#
# full
#
# grass under tree
#
# brown and gray
#
# mantel
#
# talented
#
# holding her bike up
#
# to stay warm
#
# artistic style
#
# boys hands
#
# on bike
#
# tv
#
# taupe
#
# very likely
#
# turtle
#
# decor
#
# wooden
#
# on blanket
#
# cycling
#
# by people
#
# {'filling sand', '', 'light blue', 'she finished her chores', 'shock', '13', 'hot', 'he is trying to catch frisbee', 'girl running', 'he is happy', 'throwing football', 'it got ripped out', 'playing blocks', 'seeing flower', 'each end of couch', 'comedy', 'their engagement', 'walking with dog', 'on dinner table', 'daisy', '7', 'video console', 'poodle', 'heating', 'koi', 'black and orange', 'girl and old man', 'white and orange', 'walking around instead', 'wine glass', 'watching something funny', 'none', 'shirt and jeans', 'red and purple', 'for it to sleep', 'northeast', 'lonely', 'area', 'with man', 'she standing', 'babysitter', 'jacket', 'baseball bat', 'blonde', 'reading', 'seesaw and sandbox', 'her dog', 'it will fall over', 'armrest', 'unlovable', 'blue stuffed animal', 'up', 'soup', 'terrier', 'standing beside bicycle', 'away', 'on tablecloth', 'green yellow and blue', 'books', 'it became logs', 'he is bending down', 'women', 'dog and boy on table', 'champagne', 'between 2 trees', 'messing with plant', 'kids', 'under right pane', 'mom', 'puppies', 'moon', 'left corner', 'lives nearby', 'sunset', 'what is in tree', 'both', 'transportation', 'picnic blanket and food', 'his style', 'near center of picture', 'their kids', 'circular', 'children', 'background', 'between slide and tree', 'chihuahua', 'owl in tree', 'game console', 'to pick dog', 'yarn ball', 'pillowcases', '32 each', 'cut down', 'pop cut', 'on arm of couch', 'books and plant', 'next to tree', 'on chair', 'play with dog', 'hanging', 'to feed duck', 'tray', 'right side of sky', 'playing with dog', '2 bottles of wine', 'next to sidewalk', 'no style', 'to play with', 'watermelon plant', 'food and drinks', 'marshmallows on sticks', 'spaghetti with meatballs', 'land and air', 'holding bone for dog', 'bees', 'feet', 'lillys', 'holding arm up', 'red one', 'warmth', 'shoes', 'game system', 'arm of chair', 'near window', 'paper', 'close to each other', 'blue teddy bear', 'plates', 'happiness', 'coats', 'she dropped it', 'kids show', 'he wants chair and boy is in way', 'holding bike', 'tv is funny', 'because she rode bike', 'swinging', 'beside fireplace', 'on right side', 'higher', 'on its bed', 'walking', 'on back of chair', 'right of children', 'one on carpet and one next to carpet', '5', 'man on right', 'while ago', 'not likely', 'watermelon and wine', 'poly with dog', 'bushes', 'setting table', '200', 'on left of picture', 'cake', 'log', 'leaping', 'day off', 'fowl', 'pictures', 'blue green yellow', 'around pond', 'sunglasses', 'tie back', 'under couple', 'sunny', 'scratch it', 'white and brown', 'beige', 'grandchild', '18', 'steak and hot dog', 'plate pie knife glass', 'it would be gone', 'red skateboard', 'partly sunny', 'cloth', 'climbing monkey bars', 'checks', 'ews', 'to play', 'one higher', 'it is curved', 'classy', 'nobody', 'kid', 'flying and in tree', 'hand', 'almost all', 'checker', 'honey', 'cement', 'book', 'bulldog', 'remembering', 'person taking picture', 'in front of couch', 'toward front', 'to be seen', 'in its bed', 'worrisome', 'doll house and blocks', 'her pants', 'standing on two legs', 'in grill', 'saying stop', 'wicker picnic', 'my best guess is no', 'dog is misbehaving', 'for sliding', 'wanting attention', 'afraid', 'mad at boy', 'door handle', 'boy and girl', 'tekken', 'biking', 'bottle of wine', 'brown', 'gold orange red', 'blue and white', 'not sure', 'color', 'older boy', 't', 'puppy', 'color of frisbee is blue', 'with lady', 'sunflowers', 'running away', 'to get cheese', 'to eat', 'piece of meat', 'love you', 'toward grandpa on right', 'sitting sideways', 'picking apples', 'boy on right', 'broken', 'they are playing football', 'to use in sandbox', 'on woman', 'tree can be used for christmas', 'light pink', 'turtles', 'movie', 'on ground behind man', 'lot to cook', 'playing around', 'pink flowers', 'leafy plant', 'they are yellow', 'book glass', 'gray or black', 'pie and wine', 'its on ground', 'daylight', '2 plants on either side of window ...
# The number of total words of answers in ann_vocabs will be: 2883
# The number of total words of answers in qst_vocabs will be: 1551

# %% [markdown]
# Make Vocab

# %%
def preprocessing(image_dir, annotation_dir, question_dir, output_dir, vocab_dir):
    
    dataset = dict()
    for file in os.scandir(question_dir):
        info = dict()
        
        if 'test' in file.name:
            continue
        elif 'train' in file.name:
            datatype = 'train'
        elif 'val' in file.name:
            datatype = 'val'
        
        with open(file.path, 'r') as f:
            data = json.load(f)
            questions = data['questions'].values()
    
        for ann in os.scandir(annotation_dir):
            if datatype == 'train' and 'train' in ann.name:
                with open(ann.path) as f:
                    annotations = json.load(f)['annotations'].values()
            elif datatype == 'val' and 'val' in ann.name:
                with open(ann.path) as f:
                    annotations = json.load(f)['annotations'].values()
        question_dict = {ans['question_id']: ans for ans in annotations}
        
        match_top_ans.unk_ans = 0
        num = 0
        for idx, qu in enumerate(questions):
            if (idx+1) % 1500 == 0:
                print(f'Processing {datatype} data: {idx+1}/{len(questions)}')
            qu_id = qu['question_id']
            qu_sentence = qu['question']
            qu_tokens = tokenizer(qu_sentence)
            img_id = qu['image_id']
            for dir in os.scandir(image_dir):
                if 'train' == datatype and 'train' in dir.name:
                    dir_path = dir.path
                elif 'val' == datatype and 'val' in dir.name:
                    dir_path = dir.path
                else:
                    continue
                for img in os.scandir(dir_path):
                    components = img.name.split('_')
                    image_id = components[-1].split('.')[0]
                    numeric_part = int(image_id)
                    if img_id == numeric_part:
                        img_path = img.path
            annotation_ans = question_dict[qu_id]['answers']
            
            qu_info = dict()
            qu_info.update({'img_id': img_id,
                            'img_path': img_path,
                            'qu_id': qu_id,
                            'qu_sentence': qu_sentence,
                            'qu_tokens': qu_tokens})
            
            for voc in os.scandir(vocab_dir):
                if 'ann' in voc.name:
                    if datatype == 'train' and 'train' in voc.name:
                        voc_path = voc.path
                    elif datatype == 'val' and 'val' in voc.name:
                        voc_path = voc.path
            
            all_ans, valid_ans = match_top_ans(annotation_ans, voc_path)
            qu_info.update({'all_ans': list(all_ans),
                            'valid_ans': list(valid_ans)})   

            info.update({idx: qu_info})
            
        dataset.update({datatype: info})
        print(f'Total {match_top_ans.unk_ans} out of {len(questions)} answers are <unk>')

    np.save(output_dir + '\\train.npy', np.array(dataset['train']))
    np.save(output_dir + '\\val.npy', np.array(dataset['val']))
    with open(output_dir + '\\train.json', 'w') as f:
        json.dump(dataset['train'], f)
    with open(output_dir + '\\val.json', 'w') as f:
        json.dump(dataset['val'], f)

def tokenizer(sentence):

    regex = re.compile(r'(\W+)')
    tokens = regex.split(sentence.lower())
    tokens = [w.strip() for w in tokens if len(w.strip()) > 0]
    return tokens

def match_top_ans(annotation_ans, vocab_path):
    
    if "top_ans" not in match_top_ans.__dict__:
        with open(vocab_path, 'r') as f:
            match_top_ans.top_ans = {line.strip() for line in f}
    annotation_ans = {ans['answer'] for ans in annotation_ans}
    valid_ans = match_top_ans.top_ans & annotation_ans

    if len(valid_ans) == 0:
        valid_ans = ['<unk>']
        match_top_ans.unk_ans += 1

    return annotation_ans, valid_ans

def main():

    image_dir = out_img_pth
    annotation_dir = out_ann_pth
    question_dir = out_qst_pth
    output_dir = out_data_pth
    vocab_dir = out_vocab_pth
    preprocessing(image_dir, annotation_dir, question_dir, output_dir, vocab_dir)

main()
# Out:
# Processing train data: 1500/3000
# Processing train data: 3000/3000
# Total 1 out of 3000 answers are <unk>
# Processing val data: 1500/1500
# Total 27 out of 1500 answers are <unk>
# Processing train data: 1500/3000
# Processing train data: 3000/3000
# Total 1 out of 3000 answers are <unk>
# Processing val data: 1500/1500
# Total 27 out of 1500 answers are <unk>

# %% [markdown]
# Build dataset

# %%
class VQADataset(Dataset):

    def __init__(self, input_dir, input_file, max_qu_len = 30, transform = None):

        self.input_data = np.load(os.path.join(input_dir, input_file), allow_pickle=True)
        self.qu_vocab = Vocab(input_dir+'/qst_vocabs.txt')
        self.ans_vocab = Vocab(input_dir+'/ann_vocabs.txt')
        self.max_qu_len = max_qu_len
        self.transform = transform

    def __getitem__(self, idx):

        path = self.input_data[idx]['img_path']
        img = np.array(Image.open(path).convert('RGB'))
        qu_id = self.input_data[idx]['qu_id']
        qu_tokens = self.input_data[idx]['qu_tokens']
        qu2idx = np.array([self.qu_vocab.word2idx('<pad>')] * self.max_qu_len)
        qu2idx[:len(qu_tokens)] = [self.qu_vocab.word2idx(token) for token in qu_tokens]
        sample = {'image': img, 'question': qu2idx, 'question_id': qu_id}

        if self.labeled:
            ans2idx = [self.ans_vocab.word2idx(ans) for ans in self.input_data[idx]['valid_ans']]
            ans2idx = np.random.choice(ans2idx)
            sample['answer'] = ans2idx

        if self.transform:
            sample['image'] = self.transform(sample['image'])

        return sample

    def __len__(self):

        return len(self.input_data)

def data_loader(input_dir, batch_size, max_qu_len, num_worker):

    transform = transforms.Compose([
        transforms.ToTensor(),  # convert to (C,H,W) and [0,1]
        transforms.Normalize((0.485, 0.456, 0.406), (0.229, 0.224, 0.225))  # mean=0; std=1
    ])

    vqa_dataset = {
        'train': VQADataset(
            input_dir=input_dir,
            input_file='train.npy',
            max_qu_len=max_qu_len,
            transform=transform),
        'val': VQADataset(
            input_dir=input_dir,
            input_file='val.npy',
            max_qu_len=max_qu_len,
            transform=transform)
    }

    dataloader = {
        key: DataLoader(
            dataset=vqa_dataset[key],
            batch_size=batch_size,
            shuffle=True,
            num_workers=num_worker)
        for key in ['train', 'val']
    }

    return dataloader

class Vocab:

    def __init__(self, vocab_file):

        self.vocab = self.load_vocab(vocab_file)
        self.vocab2idx = {vocab: idx for idx, vocab in enumerate(self.vocab)}
        self.vocab_size = len(self.vocab)

    def load_vocab(self, vocab_file):

        with open(vocab_file) as f:
            vocab = [v.strip() for v in f]

        return vocab

    def word2idx(self, vocab):

        if vocab in self.vocab2idx:
            return self.vocab2idx[vocab]
        else:
            return self.vocab2idx['<unk>']

    def idx2word(self, idx):

        return self.vocab[idx]

# %% [markdown]
# Late fusion models

# %%
class ImgEncoder(nn.Module):

    def __init__(self, embed_dim):

        super(ImgEncoder, self).__init__()
        self.model = models.vgg19(pretrained=True)
        in_features = self.model.classifier[-1].in_features
        self.model.classifier = nn.Sequential(*list(self.model.classifier.children())[:-1]) # remove vgg19 last layer
        self.fc = nn.Linear(in_features, embed_dim)

    def forward(self, image):

        with torch.no_grad():
            img_feature = self.model(image) # (batch, channel, height, width)
        img_feature = self.fc(img_feature)

        l2_norm = F.normalize(img_feature, p=2, dim=1).detach()
        return l2_norm

class QuEncoder(nn.Module):

    def __init__(self, qu_vocab_size, word_embed, hidden_size, num_hidden, qu_feature_size):

        super(QuEncoder, self).__init__()
        self.word_embedding = nn.Embedding(qu_vocab_size, word_embed)
        self.tanh = nn.Tanh()
        self.lstm = nn.LSTM(word_embed, hidden_size, num_hidden) # input_feature, hidden_feature, num_layer
        self.fc = nn.Linear(2*num_hidden*hidden_size, qu_feature_size)

    def forward(self, question):

        qu_embedding = self.word_embedding(question)                # (batchsize, qu_length=30, word_embed=300)
        qu_embedding = self.tanh(qu_embedding)
        qu_embedding = qu_embedding.transpose(0, 1)                 # (qu_length=30, batchsize, word_embed=300)
        _, (hidden, cell) = self.lstm(qu_embedding)                 # (num_layer=2, batchsize, hidden_size=1024)
        qu_feature = torch.cat((hidden, cell), dim=2)               # (num_layer=2, batchsize, 2*hidden_size=1024)
        qu_feature = qu_feature.transpose(0, 1)                     # (batchsize, num_layer=2, 2*hidden_size=1024)
        qu_feature = qu_feature.reshape(qu_feature.size()[0], -1)   # (batchsize, 2*num_layer*hidden_size=2048)
        qu_feature = self.tanh(qu_feature)
        qu_feature = self.fc(qu_feature)                            # (batchsize, qu_feature_size=1024)

        return qu_feature

class VQAModel(nn.Module):

    def __init__(self, feature_size, qu_vocab_size, ans_vocab_size, word_embed, hidden_size, num_hidden):

        super(VQAModel, self).__init__()
        self.img_encoder = ImgEncoder(feature_size)
        self.qu_encoder = QuEncoder(qu_vocab_size, word_embed, hidden_size, num_hidden, feature_size)
        self.dropout = nn.Dropout(0.5)
        self.tanh = nn.Tanh()
        self.fc1 = nn.Linear(feature_size, ans_vocab_size)
        self.fc2 = nn.Linear(ans_vocab_size, ans_vocab_size)

    def forward(self, image, question):

        img_feature = self.img_encoder(image)               # (batchsize, feature_size=1024)
        qst_feature = self.qu_encoder(question)
        combined_feature = img_feature * qst_feature
        combined_feature = self.dropout(combined_feature)
        combined_feature = self.tanh(combined_feature)
        combined_feature = self.fc1(combined_feature)       # (batchsize, ans_vocab_size=1000)
        combined_feature = self.dropout(combined_feature)
        combined_feature = self.tanh(combined_feature)
        logits = self.fc2(combined_feature)                 # (batchsize, ans_vocab_size=1000)

        return logits

# %% [markdown]
# Training loop

# %%
BATCH_SIZE = 150
MAX_QU_LEN = 30
NUM_WORKER = 8
FEATURE_SIZE, WORD_EMBED = 1024, 300
NUM_HIDDEN, HIDDEN_SIZE = 2, 512
LEARNING_RATE, STEP_SIZE, GAMMA = 0.001, 10, 0.1
EPOCH = 50

device = torch.device('cuda:0' if torch.cuda.is_available() else 'cpu')

def train():

    dataloader = data_loader(input_dir=out_data_pth, batch_size=BATCH_SIZE, max_qu_len=MAX_QU_LEN, num_worker=NUM_WORKER)
    qu_vocab_size = dataloader['train'].dataset.qu_vocab.vocab_size
    ans_vocab_size = dataloader["train"].dataset.ans_vocab.vocab_size

    model = VQAModel(feature_size=FEATURE_SIZE, qu_vocab_size=qu_vocab_size, ans_vocab_size=ans_vocab_size,
                     word_embed=WORD_EMBED, hidden_size=HIDDEN_SIZE, num_hidden=NUM_HIDDEN).to(device)

    optimizer = optim.Adam(model.parameters(), lr=LEARNING_RATE)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=STEP_SIZE, gamma=GAMMA)
    criterion = nn.CrossEntropyLoss()

    print('>> start training')
    start_time = time.time()
    for epoch in range(EPOCH):
        epoch_loss = {key: 0 for key in ['train', 'val']}

        model.train()
        for idx, sample in enumerate(dataloader['train']):

            image = sample['image'].to(device=device)
            question = sample['question'].to(device=device)
            label = sample['answer'].to(device=device)
            # forward
            logits = model(image, question)
            loss = criterion(logits, label)
            epoch_loss['train'] += loss.item()
            # backward
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

        model.eval()
        for idx, sample in enumerate(dataloader['val']):

            image = sample['image'].to(device=device)
            question = sample['question'].to(device=device)
            label = sample['answer'].to(device=device)
            with torch.no_grad():
                logits = model(image, question)
                loss = criterion(logits, label)
            epoch_loss['val'] += loss.item()

        # statistic
        for phase in ['train', 'val']:
            epoch_loss[phase] /= len(dataloader[phase])
            with open(os.path.join(LOG_DIR, f'{phase}_log.txt'), 'a') as f:
                f.write(str(epoch+1) + '\t' + str(epoch_loss[phase]) + '\n')
        print('Epoch:{}/{} | Training Loss: {train:6f} | Validation Loss: {val:6f}'.format(epoch+1, EPOCH, **epoch_loss))

        scheduler.step()
        early_stop = early_stopping(model, epoch_loss['val'])
        if (epoch+1) % 5 == 0:
            torch.save(model.state_dict(), os.path.join(ckpt_pth, f'model-epoch-{epoch+1}.pth'))
        if early_stop:
            print(f'>> Early stop at {epoch+1} epoch')
            break

    end_time = time.time()
    training_time = end_time - start_time
    print(f">> Finishing training | Training Time:{training_time//60:.0f}m:{training_time%60:.0f}s")

def early_stopping(model, epoch_loss, patience=7):

    early_stop = False
    if not bool(early_stopping.__dict__):
        early_stopping.best_loss = epoch_loss
        early_stopping.record_loss = epoch_loss
        early_stopping.counter = 0

    if epoch_loss < early_stopping.best_loss:
        early_stopping.best = epoch_loss
        torch.save(model.state_dict(), os.path.join(ckpt_pth, 'best_model.pth'))

    if epoch_loss > early_stopping.record_loss:
        early_stopping.counter += 1
        if early_stopping.counter >= patience:
            early_stop = True
    else:
        early_stopping.counter = 0
        early_stopping.record_loss = epoch_loss

    return early_stop

if __name__ == '__main__':

    if not os.path.exists(LOG_DIR):
        os.makedirs(LOG_DIR)
    if not os.path.exists(CKPT_DIR):
        os.makedirs(CKPT_DIR)
    train()
